# %% [markdown]
# ## Neural Network models - Leave One Participant Out CV to predict properties using 3 subwindows

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
from pandas.core.common import SettingWithCopyWarning

import warnings
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

import random
import datetime
import time
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset
import torch.optim as optim

# %%
# Initialise the random state
#num = random.randint(1, 500)
num = 58
torch.manual_seed(num)
np.random.seed(num)
print(f"The generated random seed is {num}") #347
# Out:
# The generated random seed is 58

# %% [markdown]
# ### Load data

# %%
path = "/Users/niharawarawita/Desktop/MSc Project/Data and code/complete_dataset_3subwindows.csv"
df = pd.read_csv(path)
df.head(10)
# Out:
#    participant_id  clothes_id  property_id property_name  interaction_id  \
# 0               7          14            3    smoothness               1
# 1               7          14            3    smoothness               1
# 2               7          14            3    smoothness               1
# 3               7          14            4     thickness               2
# 4               7          14            4     thickness               2
# 5               7          14            4     thickness               2
# 6               7          14            5        warmth               3
# 7               7          14            5        warmth               3
# 8               7          14            5        warmth               3
# 9               7          14            6   flexibility               4
#
#    rating rating_level  rating_level_num  sub_window_num  \
# 0       3       medium                 2               1
# 1       3       medium                 2               2
# 2       3       medium                 2               3
# 3       5       medium                 2               1
# 4       5       medium                 2               2
# 5       5       medium                 2               3
# 6       4       medium                 2               1
# 7       4       medium                 2               2
# 8       4       medium                 2               3
# 9       1          low                 1               1
#
#       subwindow_start_time       subwindow_end_time  max_ch1_Hand0  \
# 0  2021-08-05 13:21:31.481  2021-08-05 13:21:32.468       0.504132
# 1  2021-08-05 13:21:32.495  2021-08-05 13:21:33.464       0.504132
# 2  2021-08-05 13:21:33.513  2021-08-05 13:21:46.475       0.685950
# 3  2021-08-05 13:22:02.060  2021-08-05 13:22:03.029       0.512397
# 4  2021-08-05 13:22:03.061  2021-08-05 13:22:04.047       0.504132
# 5  2021-08-05 13:22:04.089  2021-08-05 13:22:17.056       0.553719
# 6  2021-08-05 13:22:31.916  2021-08-05 13:22:32.885       0.541322
# 7  2021-08-05 13:22:32.921  2021-08-05 13:22:33.908       0.516529
# 8  2021-08-05 13:22:33.943  2021-08-05 13:22:46.901       0.504132
# 9  2021-08-05 13:23:00.627  2021-08-05 13:23:01.621       0.553719
#
#    max_ch2_Hand0  max_ch3_Hand0  max_ch4_Hand0  max_ch5_Hand0  max_ch6_Hand0  \
# 0       0.620513       0.675978       0.500000       0.759036       0.652406
# 1       0.620513       0.675978       0.500000       0.759036       0.663102
# 2       0.728205       0.849162       0.607438       0.777108       0.700535
# 3       0.661538       0.754190       0.512397       0.759036       0.673797
# 4       0.635897       0.737430       1.000000       0.746988       0.652406
# 5       0.702564       0.798883       1.000000       0.843374       0.754011
# 6       0.635897       0.737430       1.000000       0.969880       0.754011
# 7       0.630769       0.715084       1.000000       0.771084       0.743316
# 8       0.620513       0.675978       1.000000       0.753012       0.652406
# 9       0.907692       0.938548       1.000000       0.939759       0.711230
#
#    max_ch7_Hand0  max_ch8_Hand0  mean_ch1_Hand0  mean_ch2_Hand0  \
# 0        0.76250       0.666667        0.497498        0.612780
# 1        0.75625       0.666667        0.497417        0.612789
# 2       4.806996      10.779876       6.534156     486.415887    1142.095742
# 3      11.152448       9.963270      16.088213    1150.663729    1135.642103
# 4       5.253641       7.297097       3.331552     548.393076     819.998059
# 5       5.948223       5.273546       4.484067     548.302677     461.158083
# 6       2.240763       4.172808      10.907450     282.637410     364.125511
# 7       0.890300       2.983282       9.940538      74.094374     227.550948
# 8       3.198438       7.364610       9.584111     272.472840     618.347885
# 9       9.319012       8.356834       6.251922     907.661263     745.336220
#
#    std_AJz_Hand1
# 0     898.072858
# 1     769.701026
# 2     625.153662
# 3    2119.655762
# 4     375.285448
# 5     430.242493
# 6    1378.104484
# 7     905.421557
# 8    1022.027358
# 9     543.331560

# %%
# Remove enjoyment as we are only considering physical properties
print(df.shape)
physical_df = df[df.property_name!='enjoyment']
physical_df.shape
# Out:
# (1512, 191)
# (1260, 191)

# %%
physical_df.head()
# Out:
#    participant_id  clothes_id  property_id property_name  interaction_id  \
# 0               7          14            3    smoothness               1
# 1               7          14            3    smoothness               1
# 2               7          14            3    smoothness               1
# 3               7          14            4     thickness               2
# 4               7          14            4     thickness               2
#
#    rating rating_level  rating_level_num  sub_window_num  \
# 0       3       medium                 2               1
# 1       3       medium                 2               2
# 2       3       medium                 2               3
# 3       5       medium                 2               1
# 4       5       medium                 2               2
#
#       subwindow_start_time       subwindow_end_time  max_ch1_Hand0  \
# 0  2021-08-05 13:21:31.481  2021-08-05 13:21:32.468       0.504132
# 1  2021-08-05 13:21:32.495  2021-08-05 13:21:33.464       0.504132
# 2  2021-08-05 13:21:33.513  2021-08-05 13:21:46.475       0.685950
# 3  2021-08-05 13:22:02.060  2021-08-05 13:22:03.029       0.512397
# 4  2021-08-05 13:22:03.061  2021-08-05 13:22:04.047       0.504132
#
#    max_ch2_Hand0  max_ch3_Hand0  max_ch4_Hand0  max_ch5_Hand0  max_ch6_Hand0  \
# 0       0.620513       0.675978       0.500000       0.759036       0.652406
# 1       0.620513       0.675978       0.500000       0.759036       0.663102
# 2       0.728205       0.849162       0.607438       0.777108       0.700535
# 3       0.661538       0.754190       0.512397       0.759036       0.673797
# 4       0.635897       0.737430       1.000000       0.746988       0.652406
#
#    max_ch7_Hand0  max_ch8_Hand0  mean_ch1_Hand0  mean_ch2_Hand0  \
# 0        0.76250       0.666667        0.497498        0.612780
# 1        0.75625       0.666667        0.497417        0.612789
# 2        0.87500       0.733333        0.497469        0.612832
# 3        0.76250       0.677778        0.497326        0.612893
# 4        0.76250       0.672222        0.497305        0.612760
#
#    mean_ch3_Hand0  mean_ch4_Hand0  mean_ch5_Hand0  mean_ch6_Hand0  \
# 0        0.665895        0.492285        0.718526        0.636907
# 1        0.666077        0.492186        0.718908        0.637194
# 2        0.666206        0.492255        0.718535        0.637126
# 3        0.666100        0.484996        0.718373        0.637000
# 4        0.666103        0.539813        0.720609        0.636990
#
#    mean_ch7_Hand0  mean_ch8_Hand0  std_ch1_Hand0  std_ch2_Hand0  \
# 0        0.748853        0.660720       0.002329       0.002760
# 1        0.748828        0.660428       0.002321       0.002785
#
#    mean_AJx_Hand0  mean_AJy_Hand0  mean_AJz_Hand0  std_w_Hand0  std_x_Hand0  \
# 0      -18.896953       -5.997847       29.264918     0.004033     0.001122
# 1       26.988689       -7.739067      -51.168052     0.002767     0.001331
# 2        1.585695       -0.670795        3.401131     0.005331     0.007307
# 3       39.024051      -14.919398       87.718777     0.002371     0.002726
# 4        7.439429        3.549816        8.698628     0.001243     0.001357
#
#    std_y_Hand0  std_z_Hand0  std_AVx_Hand0  std_AVy_Hand0  std_AVz_Hand0  \
# 0     0.003172     0.000812       0.034035       0.027288       0.100030
# 1     0.002246     0.000222       0.031651       0.021172       0.067094
# 2     0.004144     0.004806       0.054181       0.088889       0.070436
# 3     0.000789     0.001891       0.062111       0.086016       0.096223
# 4     0.001932     0.000563       0.026385       0.029268       0.078408
#
#    std_AAx_Hand0  std_AAy_Hand0  std_AAz_Hand0  std_AJx_Hand0  std_AJy_Hand0  \
# 0       1.808784       1.349269       6.515867     214.502864     135.316892
# 1       1.891410       1.482885       4.074346     324.990077     135.612823
# 2       2.939673       3.487398       4.355037     268.202026     277.300592
# 3       3.429911       6.023802       6.526026     441.445219     477.288587
# 4       1.107083       1.317382       4.622568      85.712120     106.001201
#
#    std_AJz_Hand0  max_w_Hand1  max_x_Hand1  max_y_Hand1  max_z_Hand1  \
# 0     572.754308     0.618680    -0.175326    -0.753378    -0.128901
# 1     500.564267     0.618863    -0.150822    -0.754349    -0.114060
# 2     448.167800     0.647831    -0.136257    -0.732800    -0.102524
# 3     875.383706     0.733975    -0.215858    -0.515914    -0.370804
# 4     406.024850     0.722931    -0.229336    -0.534479    -0.366098
#
#    max_AVx_Hand1  max_AVy_Hand1  max_AVz_Hand1  max_AAx_Hand1  max_AAy_Hand1  \
# 0       0.215491       0.583907       0.275227      21.603607      56.450019
# 1       0.383834       0.784153       0.553013      11.380460      29.010612
# 2       0.879971       1.989502       1.122907      49.389847      85.475258
# 3       0.271520       0.413471       0.793342      29.883033      33.672845
# 4       0.563110       0.565189       0.085749      12.485845      20.251992
#
#    max_AAz_Hand1  max_AJx_Hand1  max_AJy_Hand1  max_AJz_Hand1  mean_w_Hand1  \
# 0      29.424453    2797.763022    9050.317251    2366.953044      0.602964
# 1      33.358820    2752.365093    6546.331906    2181.850987      0.596188
# 2      61.100255    4256.775521    8723.328584    4294.956003      0.619735
# 3      86.168465    3965.979471    4675.769180   11733.432855      0.726422
# 4       7.395605    1233.738922    2111.723609     964.527774      0.715442
#
#    mean_x_Hand1  mean_y_Hand1  mean_z_Hand1  mean_AVx_Hand1  mean_AVy_Hand1  \
# 0     -0.177295     -0.766545     -0.131596       -0.011132       -0.035192
# 1     -0.163353     -0.775710     -0.124714        0.021907        0.013755
# 2     -0.153120     -0.759202     -0.124798        0.001542        0.004674
# 3     -0.222149     -0.527491     -0.380252       -0.081652       -0.042828
# 4     -0.232278     -0.544587     -0.370770        0.045293        0.053730
#
#    mean_AVz_Hand1  mean_AAx_Hand1  mean_AAy_Hand1  mean_AAz_Hand1  \
# 0       -0.000290       -0.692534       -0.994509       -0.440578
# 1        0.012748       -1.111580       -0.334962        0.021466
# 2       -0.003122        0.079193        0.174868        0.141086
# 3        0.027246       -1.330705       -1.340691        1.024436
# 4       -0.001529       -0.013939        0.110153       -0.246766
#
#    mean_AJx_Hand1  mean_AJy_Hand1  mean_AJz_Hand1  std_w_Hand1  std_x_Hand1  \
# 0       19.388504       94.341574      -56.539654     0.007223     0.001357
# 1      -90.668628      -64.601575       35.073660     0.015482     0.009833
# 2        4.852312       18.350814        2.436863     0.012631     0.008083
# 3      -49.463745      -93.159203      -58.539333     0.005213     0.004116
# 4      -31.768089      -36.879092       -7.538979     0.006682     0.002770
#
#    std_y_Hand1  std_z_Hand1  std_AVx_Hand1  std_AVy_Hand1  std_AVz_Hand1  \
# 0     0.006089     0.001773       0.140168       0.419609       0.109731
# 1     0.014861     0.007212       0.166403       0.417988       0.173217
# 2     0.012225     0.012151       0.123687       0.282669       0.113030
# 3     0.008078     0.003958       0.198462       0.183171       0.155875
# 4     0.009360     0.002573       0.181719       0.217952       0.053026
#
#    std_AAx_Hand1  std_AAy_Hand1  std_AAz_Hand1  std_AJx_Hand1  std_AJy_Hand1  \
# 0       8.409602      20.970763       7.985693     769.853603    1878.284384
# 1       7.359519      14.858287       9.153837     744.182656    1454.186126
# 2       4.806996      10.779876       6.534156     486.415887    1142.095742
# 3      11.152448       9.963270      16.088213    1150.663729    1135.642103
# 4       5.253641       7.297097       3.331552     548.393076     819.998059
#
#    std_AJz_Hand1
# 0     898.072858
# 1     769.701026
# 2     625.153662
# 3    2119.655762
# 4     375.285448

# %% [markdown]
# ### Normalise the data

# %%
starting_index = 11
# Obtain a df of features
features_df = physical_df.iloc[:,starting_index:]
features_df.head()
# Out:
#    max_ch1_Hand0  max_ch2_Hand0  max_ch3_Hand0  max_ch4_Hand0  max_ch5_Hand0  \
# 0       0.504132       0.620513       0.675978       0.500000       0.759036
# 1       0.504132       0.620513       0.675978       0.500000       0.759036
# 2       0.685950       0.728205       0.849162       0.607438       0.777108
# 3       0.512397       0.661538       0.754190       0.512397       0.759036
# 4       0.504132       0.635897       0.737430       1.000000       0.746988
#
#    max_ch6_Hand0  max_ch7_Hand0  max_ch8_Hand0  mean_ch1_Hand0  \
# 0       0.652406        0.76250       0.666667        0.497498
# 1       0.663102        0.75625       0.666667        0.497417
# 2       0.700535        0.87500       0.733333        0.497469
# 3       0.673797        0.76250       0.677778        0.497326
# 4       0.652406        0.76250       0.672222        0.497305
#
#    mean_ch2_Hand0  mean_ch3_Hand0  mean_ch4_Hand0  mean_ch5_Hand0  \
# 0        0.612780        0.665895        0.492285        0.718526
# 1        0.612789        0.666077        0.492186        0.718908
# 2        0.612832        0.666206        0.492255        0.718535
# 3        0.612893        0.666100        0.484996        0.718373
# 4        0.612760        0.666103        0.539813        0.720609
#
#    mean_ch6_Hand0  mean_ch7_Hand0  mean_ch8_Hand0  std_ch1_Hand0  \
# 0        0.636907        0.748853        0.660720       0.002329
# 1        0.637194        0.748828        0.660428       0.002321
#
#    mean_AAz_Hand0  mean_AJx_Hand0  mean_AJy_Hand0  mean_AJz_Hand0  \
# 0        0.213198      -18.896953       -5.997847       29.264918
# 1       -0.006631       26.988689       -7.739067      -51.168052
# 2        0.050148        1.585695       -0.670795        3.401131
# 3       -0.114937       39.024051      -14.919398       87.718777
# 4        0.191972        7.439429        3.549816        8.698628
#
#    std_w_Hand0  std_x_Hand0  std_y_Hand0  std_z_Hand0  std_AVx_Hand0  \
# 0     0.004033     0.001122     0.003172     0.000812       0.034035
# 1     0.002767     0.001331     0.002246     0.000222       0.031651
# 2     0.005331     0.007307     0.004144     0.004806       0.054181
# 3     0.002371     0.002726     0.000789     0.001891       0.062111
# 4     0.001243     0.001357     0.001932     0.000563       0.026385
#
#    std_AVy_Hand0  std_AVz_Hand0  std_AAx_Hand0  std_AAy_Hand0  std_AAz_Hand0  \
# 0       0.027288       0.100030       1.808784       1.349269       6.515867
# 1       0.021172       0.067094       1.891410       1.482885       4.074346
# 2       0.088889       0.070436       2.939673       3.487398       4.355037
# 3       0.086016       0.096223       3.429911       6.023802       6.526026
# 4       0.029268       0.078408       1.107083       1.317382       4.622568
#
#    std_AJx_Hand0  std_AJy_Hand0  std_AJz_Hand0  max_w_Hand1  max_x_Hand1  \
# 0     214.502864     135.316892     572.754308     0.618680    -0.175326
# 1     324.990077     135.612823     500.564267     0.618863    -0.150822
# 2     268.202026     277.300592     448.167800     0.647831    -0.136257
# 3     441.445219     477.288587     875.383706     0.733975    -0.215858
# 4      85.712120     106.001201     406.024850     0.722931    -0.229336
#
#    max_y_Hand1  max_z_Hand1  max_AVx_Hand1  max_AVy_Hand1  max_AVz_Hand1  \
# 0    -0.753378    -0.128901       0.215491       0.583907       0.275227
# 1    -0.754349    -0.114060       0.383834       0.784153       0.553013
# 2    -0.732800    -0.102524       0.879971       1.989502       1.122907
# 3    -0.515914    -0.370804       0.271520       0.413471       0.793342
# 4    -0.534479    -0.366098       0.563110       0.565189       0.085749
#
#    max_AAx_Hand1  max_AAy_Hand1  max_AAz_Hand1  max_AJx_Hand1  max_AJy_Hand1  \
# 0      21.603607      56.450019      29.424453    2797.763022    9050.317251
# 1      11.380460      29.010612      33.358820    2752.365093    6546.331906
# 2      49.389847      85.475258      61.100255    4256.775521    8723.328584
# 3      29.883033      33.672845      86.168465    3965.979471    4675.769180
# 4      12.485845      20.251992       7.395605    1233.738922    2111.723609
#
#    max_AJz_Hand1  mean_w_Hand1  mean_x_Hand1  mean_y_Hand1  mean_z_Hand1  \
# 0    2366.953044      0.602964     -0.177295     -0.766545     -0.131596
# 1    2181.850987      0.596188     -0.163353     -0.775710     -0.124714
# 2    4294.956003      0.619735     -0.153120     -0.759202     -0.124798
# 3   11733.432855      0.726422     -0.222149     -0.527491     -0.380252
# 4     964.527774      0.715442     -0.232278     -0.544587     -0.370770
#
#    mean_AVx_Hand1  mean_AVy_Hand1  mean_AVz_Hand1  mean_AAx_Hand1  \
# 0       -0.011132       -0.035192       -0.000290       -0.692534
# 1        0.021907        0.013755        0.012748       -1.111580
# 2        0.001542        0.004674       -0.003122        0.079193
# 3       -0.081652       -0.042828        0.027246       -1.330705
# 4        0.045293        0.053730       -0.001529       -0.013939
#
#    mean_AAy_Hand1  mean_AAz_Hand1  mean_AJx_Hand1  mean_AJy_Hand1  \
# 0       -0.994509       -0.440578       19.388504       94.341574
# 1       -0.334962        0.021466      -90.668628      -64.601575
# 2        0.174868        0.141086        4.852312       18.350814
# 3       -1.340691        1.024436      -49.463745      -93.159203
# 4        0.110153       -0.246766      -31.768089      -36.879092
#
#    mean_AJz_Hand1  std_w_Hand1  std_x_Hand1  std_y_Hand1  std_z_Hand1  \
# 0      -56.539654     0.007223     0.001357     0.006089     0.001773
# 1       35.073660     0.015482     0.009833     0.014861     0.007212
# 2        2.436863     0.012631     0.008083     0.012225     0.012151
# 3      -58.539333     0.005213     0.004116     0.008078     0.003958
# 4       -7.538979     0.006682     0.002770     0.009360     0.002573
#
#    std_AVx_Hand1  std_AVy_Hand1  std_AVz_Hand1  std_AAx_Hand1  std_AAy_Hand1  \
# 0       0.140168       0.419609       0.109731       8.409602      20.970763
# 1       0.166403       0.417988       0.173217       7.359519      14.858287
# 2       0.123687       0.282669       0.113030       4.806996      10.779876
# 3       0.198462       0.183171       0.155875      11.152448       9.963270
# 4       0.181719       0.217952       0.053026       5.253641       7.297097
#
#    std_AAz_Hand1  std_AJx_Hand1  std_AJy_Hand1  std_AJz_Hand1
# 0       7.985693     769.853603    1878.284384     898.072858
# 1       9.153837     744.182656    1454.186126     769.701026
# 2       6.534156     486.415887    1142.095742     625.153662
# 3      16.088213    1150.663729    1135.642103    2119.655762
# 4       3.331552     548.393076     819.998059     375.285448

# %%
normalised_features_df = features_df.copy()
print(normalised_features_df.shape)
# Out:
# (1260, 180)

# %%
# create scaler
scaler = MinMaxScaler(feature_range=(-1,1)) # As this is the range of the activation function - tanh

# fit scaler and apply transform
normalised_features_df[normalised_features_df.columns] = scaler.fit_transform(features_df[features_df.columns])
normalised_features_df.shape
# Out:
# (1260, 180)

# %%
df_info = physical_df.iloc[:, :starting_index]
df_info.head()
# Out:
#    participant_id  clothes_id  property_id property_name  interaction_id  \
# 0               7          14            3    smoothness               1
# 1               7          14            3    smoothness               1
# 2               7          14            3    smoothness               1
# 3               7          14            4     thickness               2
# 4               7          14            4     thickness               2
#
#    rating rating_level  rating_level_num  sub_window_num  \
# 0       3       medium                 2               1
# 1       3       medium                 2               2
# 2       3       medium                 2               3
# 3       5       medium                 2               1
# 4       5       medium                 2               2
#
#       subwindow_start_time       subwindow_end_time
# 0  2021-08-05 13:21:31.481  2021-08-05 13:21:32.468
# 1  2021-08-05 13:21:32.495  2021-08-05 13:21:33.464
# 2  2021-08-05 13:21:33.513  2021-08-05 13:21:46.475
# 3  2021-08-05 13:22:02.060  2021-08-05 13:22:03.029
# 4  2021-08-05 13:22:03.061  2021-08-05 13:22:04.047

# %%
normalised_df = pd.concat([df_info,normalised_features_df], axis=1)
normalised_df.shape
# Out:
# (1260, 191)

# %% [markdown]
# ### Create X and y data

# %%
def create_X_2d(df, features_starting_idx):
    
    X_2d = df.iloc[:,features_starting_idx:].values
    
    X_tensor_2d = torch.Tensor(X_2d)    
    return X_tensor_2d

# %%
def create_y_train_for_2d_X(df, predicting_feature = 'property_id', output_as_tensor='Yes'):
    # CreatE an instance of a one-hot-encoder
    encoder = OneHotEncoder(handle_unknown='ignore')

    # Perform one-hot encoding on the specified column 
    encoder_df = pd.DataFrame(encoder.fit_transform(df[[predicting_feature]]).toarray())
    
    # Convert to a numpy array
    y_train = encoder_df.to_numpy()
    
    if output_as_tensor == 'Yes':
        # Convert to a tensor
        y_train = torch.Tensor(y_train)

    return y_train

# %%
def create_y_test_for_2d_X(df, predicting_feature = 'property_id'):   
    y_test = df[predicting_feature].values
    #if predicting_feature == 'property_id':
       # y_test = y_test - 3
    if predicting_feature == 'rating_level_num':
        y_test = y_test - 1
    
    y_test_tensor = torch.Tensor(y_test)    
    y_test_tensor = y_test_tensor.type(torch.LongTensor)
    
    return y_test_tensor

# %%
def create_X_3d(df, features_starting_idx):
    dim1 = df.new_interaction_id.nunique()
    #print(dim1)
    dim2 = 3
    dim3 = df.iloc[:,features_starting_idx:].shape[1]
        
    X = np.zeros((dim1, dim2, dim3)) 

    itr_id_lst = df.new_interaction_id.unique().tolist()
    #print(itr_id_lst[0], itr_id_lst[-1])

    for i in range(len(itr_id_lst)): #range(len(itr_id_lst)):
        itr_id = itr_id_lst[i]
        itr_id_df = df[df.new_interaction_id==itr_id]  
        
        for j in range(itr_id_df.shape[0]):
            vals_arr = itr_id_df.iloc[j,features_starting_idx:].values

            X[i,j] = vals_arr
    
    X_tensor = torch.Tensor(X)    
    return X_tensor

# %%
def create_y_train_for_3d_X(df, predicting_feature = 'property_id'):
    # Create a dataset with only the required columns
    df2 = df[['new_interaction_id', 'property_id', 'rating_level_num']]

    # Remove duplicates
    df2.drop_duplicates(keep='first', inplace=True)

    # Reset the indexes
    df2.reset_index(drop=True, inplace=True) 
    
    ## Create y train
    # CreatE an instance of a one-hot-encoder
    encoder = OneHotEncoder(handle_unknown='ignore')

    # Perform one-hot encoding on the specified column 
    encoder_df = pd.DataFrame(encoder.fit_transform(df2[[predicting_feature]]).toarray())
    
    # Convert to a numpy array
    y_train = encoder_df.to_numpy()
    
    # Convert to a tensor
    y_train = torch.Tensor(y_train)
  
    return y_train

# %%
def create_y_test_for_3d_X(df, predicting_feature = 'property_id'):
    # Create a dataset with only the required columns
    df2 = df[['new_interaction_id', 'property_id', 'rating_level_num']]

    # Remove duplicates
    df2.drop_duplicates(keep='first', inplace=True)

    # Reset the indexes
    df2.reset_index(drop=True, inplace=True) 
    
    y_test = df2[predicting_feature].values
    #if predicting_feature == 'property_id':
       # y_test = y_test - 3
    if predicting_feature == 'rating_level_num':
        y_test = y_test - 1
    
    y_test = torch.Tensor(y_test)    
    y_test = y_test.type(torch.LongTensor)
    
    return y_test

# %% [markdown]
# ## Model 3 - LSTM + fully connected layers using all 180 features

# %%
# Add a column to interact

normalised_df.insert(5, "new_interaction_id", None)
normalised_df['new_interaction_id'] = normalised_df.groupby(['participant_id', 'clothes_id', 'property_id'], sort=False).ngroup() + 1
normalised_df.head()
# Out:
#    participant_id  clothes_id  property_id property_name  interaction_id  \
# 0               7          14            3    smoothness               1
# 1               7          14            3    smoothness               1
# 2               7          14            3    smoothness               1
# 3               7          14            4     thickness               2
# 4               7          14            4     thickness               2
#
#    new_interaction_id  rating rating_level  rating_level_num  sub_window_num  \
# 0                   1       3       medium                 2               1
# 1                   1       3       medium                 2               2
# 2                   1       3       medium                 2               3
# 3                   2       5       medium                 2               1
# 4                   2       5       medium                 2               2
#
#       subwindow_start_time       subwindow_end_time  max_ch1_Hand0  \
# 0  2021-08-05 13:21:31.481  2021-08-05 13:21:32.468       0.008264
# 1  2021-08-05 13:21:32.495  2021-08-05 13:21:33.464       0.008264
# 2  2021-08-05 13:21:33.513  2021-08-05 13:21:46.475       0.371900
# 3  2021-08-05 13:22:02.060  2021-08-05 13:22:03.029       0.024794
# 4  2021-08-05 13:22:03.061  2021-08-05 13:22:04.047       0.008264
#
#    max_ch2_Hand0  max_ch3_Hand0  max_ch4_Hand0  max_ch5_Hand0  max_ch6_Hand0  \
# 0       0.241026       0.351956       0.000000       0.518072       0.304812
# 1       0.241026       0.351956       0.000000       0.518072       0.326204
# 2       0.456410       0.698324       0.214876       0.554216       0.401070
# 3       0.323076       0.508380       0.024794       0.518072       0.347594
# 4       0.271794       0.474860       1.000000       0.493976       0.304812
#
#    max_ch7_Hand0  max_ch8_Hand0  mean_ch1_Hand0  mean_ch2_Hand0  \
# 0         0.5250       0.333334        0.106673        0.460704
# 1         0.5125       0.333334        0.106493        0.460726
# 2         0.7500       0.466666        0.106607        0.460828
# 3         0.5250       0.355556        0.106290        0.460972
# 4         0.5250       0.344444        0.106242        0.460656
#
#    mean_ch3_Hand0  mean_ch4_Hand0  mean_ch5_Hand0  mean_ch6_Hand0  \
# 0        0.603821        0.332895        0.988182        0.603340
# 1        0.604258        0.332627        0.989237        0.604063
# 2        0.604570        0.332814        0.988206        0.603891
# 3        0.604313        0.313160        0.987758        0.603574
# 4        0.604321        0.461582        0.993944        0.603550
#
#    mean_ch7_Hand0  mean_ch8_Hand0  std_ch1_Hand0  std_ch2_Hand0  \
# 0        0.956492        0.570180      -0.985256      -0.955814
# 1        0.956428        0.569485      -0.985302      -0.955408
# 2        0.956325        0.570097      -0.929447      -0.889868
# 3        0.956000        0.570496      -0.973885      -0.769312
# 4        0.956301        0.571031      -0.978222      -0.882761
#
#    std_ch3_Hand0  std_ch4_Hand0  std_ch5_Hand0  std_ch6_Hand0  std_ch7_Hand0  \
# 0      -0.949743      -0.982661      -0.964160      -0.961455      -0.967675
# 1      -0.953098      -0.982313      -0.963152      -0.960226      -0.973370
# 2      -0.848290      -0.938200      -0.967514      -0.963592      -0.951021
# 3      -0.646640      -0.542316      -0.959053      -0.953471      -0.953027
# 4      -0.812289      -0.244749      -0.955828      -0.965656      -0.957653
#
#    std_ch8_Hand0  max_ch1_Hand1  max_ch2_Hand1  max_ch3_Hand1  max_ch4_Hand1  \
# 2     -0.974885      -0.860036      -0.066929       0.371303      -0.933867
# 3     -0.989439      -0.780970       0.217063       0.531257      -0.933454
# 4     -0.991097      -0.787810       0.220692       0.512772      -0.933442
#
#    mean_Vy_Hand0  mean_Vz_Hand0  mean_Jx_Hand0  mean_Jy_Hand0  mean_Jz_Hand0  \
# 0       0.811927       0.982952       0.254368      -0.403098      -0.049889
# 1       0.810666       0.983088       0.290017      -0.399952      -0.063952
# 2       0.810398       0.983074       0.286297      -0.384958      -0.094139
# 3       0.811022       0.983230       0.338205      -0.423843      -0.058901
# 4       0.811966       0.983130       0.283786      -0.388435      -0.069223
#
#    std_Ax_Hand0  std_Ay_Hand0  std_Az_Hand0  std_Vx_Hand0  std_Vy_Hand0  \
# 0     -0.980355     -0.978590     -0.971579     -0.999582     -0.998769
# 1     -0.980837     -0.987158     -0.972410     -0.999501     -0.999196
# 2     -0.931562     -0.955515     -0.938812     -0.998115     -0.997425
# 3     -0.938578     -0.959875     -0.950371     -0.998862     -0.996670
# 4     -0.971376     -0.978353     -0.970594     -0.999382     -0.998659
#
#    std_Vz_Hand0  std_Jx_Hand0  std_Jy_Hand0  std_Jz_Hand0  max_Ax_Hand1  \
# 0     -0.999741     -0.970096     -0.969547     -0.959107     -0.008904
# 1     -0.999715     -0.964449     -0.975868     -0.951614     -0.032078
# 2     -0.999605     -0.919744     -0.955536     -0.947626      0.027038
# 3     -0.999557     -0.907017     -0.930937     -0.932379      0.001027
# 4     -0.999722     -0.959130     -0.973661     -0.956440     -0.010796
#
#    max_Ay_Hand1  max_Az_Hand1  max_Vx_Hand1  max_Vy_Hand1  max_Vz_Hand1  \
# 0     -0.539589     -0.799247     -0.999770     -0.999676     -0.999829
# 1     -0.524511     -0.783484     -0.999776     -0.999718     -0.999871
# 2     -0.468722     -0.663037     -0.999630     -0.999517     -0.999341
# 3     -0.474753     -0.302102     -0.999712     -0.999856     -0.999810
# 4     -0.495485     -0.369196     -0.999608     -0.999750     -0.999927
#
#    max_Jx_Hand1  max_Jy_Hand1  max_Jz_Hand1  mean_Ax_Hand1  mean_Ay_Hand1  \
# 0     -0.969993     -0.964493     -0.964812       0.940450      -0.149387
# 1     -0.976114     -0.978442     -0.947481       0.931915      -0.135401
# 2     -0.915112     -0.911520     -0.920846       0.957942      -0.134685
# 3     -0.957517     -0.975613     -0.943979       0.879963      -0.029369
# 4     -0.976512     -0.988184     -0.979947       0.912658      -0.039862
#
#    mean_Az_Hand1  mean_Vx_Hand1  mean_Vy_Hand1  mean_Vz_Hand1  mean_Jx_Hand1  \
# 0      -0.560164      -0.948797      -0.672082      -0.517004      -0.000298
# 1      -0.587195      -0.945905      -0.668924      -0.519070      -0.038647
# 2      -0.510870      -0.947170      -0.671717      -0.518796      -0.016697
# 3       0.225668      -0.949928      -0.675979      -0.518851       0.011940
# 4       0.164443      -0.945406      -0.671301      -0.519284      -0.024251
#
#    mean_Jy_Hand1  mean_Jz_Hand1  std_Ax_Hand1  std_Ay_Hand1  std_Az_Hand1  \
# 0       0.091853      -0.352547     -0.951443     -0.968661     -0.916396
# 0        0.066262       -0.175653        0.393163        0.516941
# 1        0.080855       -0.200138        0.411597        0.532444
# 2        0.063092       -0.130562        0.425847        0.536458
# 3        0.097082       -0.212941        0.383487        0.566097
# 4        0.064875       -0.136004        0.424038        0.523444
#
#    mean_AJx_Hand1  mean_AJy_Hand1  mean_AJz_Hand1  std_w_Hand1  std_x_Hand1  \
# 0        0.205953        0.010220        0.362682    -0.945791    -0.988273
# 1        0.156379       -0.010669        0.380314    -0.883817    -0.915007
# 2        0.199406        0.000233        0.374032    -0.905207    -0.930134
# 3        0.174940       -0.014423        0.362297    -0.960879    -0.964423
# 4        0.182910       -0.007026        0.372112    -0.949858    -0.976060
#
#    std_y_Hand1  std_z_Hand1  std_AVx_Hand1  std_AVy_Hand1  std_AVz_Hand1  \
# 0    -0.961864    -0.984522      -0.945357      -0.901453      -0.964430
# 1    -0.906932    -0.937042      -0.935129      -0.901833      -0.943851
# 2    -0.923439    -0.893928      -0.951782      -0.933614      -0.963361
# 3    -0.949411    -0.965449      -0.922631      -0.956981      -0.949473
# 4    -0.941382    -0.977540      -0.929159      -0.948813      -0.982811
#
#    std_AAx_Hand1  std_AAy_Hand1  std_AAz_Hand1  std_AJx_Hand1  std_AJy_Hand1  \
# 0      -0.962025      -0.963768      -0.965779      -0.989064      -0.991021
# 1      -0.966767      -0.974329      -0.960774      -0.989429      -0.993049
# 2      -0.978293      -0.981375      -0.972000      -0.993090      -0.994541
# 3      -0.949640      -0.982786      -0.931058      -0.983655      -0.994571
# 4      -0.976277      -0.987392      -0.985723      -0.992210      -0.996080
#
#    std_AJz_Hand1
# 0      -0.988550
# 1      -0.990187
# 2      -0.992029
# 3      -0.972975
# 4      -0.995215

# %%
# Obtain features for each hand
hand1_emg = normalised_df.iloc[:,35+1:59+1]

hand0_acc = normalised_df.iloc[:,59+1:86+1]
hand1_acc = normalised_df.iloc[:,86+1:113+1]

hand0_qua = normalised_df.iloc[:,113+1:152+1]
hand1_qua = normalised_df.iloc[:,152+1:]

df_info = normalised_df.iloc[:,:11+1]

# Combine the data to ceate a df for each hand
emg_0 = normalised_df.iloc[:,:35+1]
emg_1 = pd.concat([df_info, hand1_emg], axis=1)

hand_0 = pd.concat([emg_0, hand0_acc, hand0_qua], axis=1)
hand_1 = pd.concat([df_info, hand1_emg, hand1_acc, hand1_qua], axis=1)

# %%
print(hand_0.shape)
print(hand_1.shape)

print(emg_0.shape)
print(emg_1.shape)
# Out:
# (1260, 102)
# (1260, 102)
# (1260, 36)
# (1260, 36)

# %%
hand_0.head()
# Out:
#    participant_id  clothes_id  property_id property_name  interaction_id  \
# 0               7          14            3    smoothness               1
# 1               7          14            3    smoothness               1
# 2               7          14            3    smoothness               1
# 3               7          14            4     thickness               2
# 4               7          14            4     thickness               2
#
#    new_interaction_id  rating rating_level  rating_level_num  sub_window_num  \
# 0                   1       3       medium                 2               1
# 1                   1       3       medium                 2               2
# 2                   1       3       medium                 2               3
# 3                   2       5       medium                 2               1
# 4                   2       5       medium                 2               2
#
#       subwindow_start_time       subwindow_end_time  max_ch1_Hand0  \
# 2      -0.997233      0.095384      0.565638      0.180028     -0.884701
# 3      -0.994872      0.149485      0.518506      0.023741     -0.906125
# 4      -0.998916      0.143814      0.526373      0.018387     -0.904054
#
#    mean_AVx_Hand0  mean_AVy_Hand0  mean_AVz_Hand0  mean_AAx_Hand0  \
# 0        0.136416       -0.003829        0.514555        0.222445
# 1        0.134640       -0.001768        0.525639        0.225323
# 2        0.137249       -0.002091        0.536092        0.228219
# 3        0.139425        0.010845        0.517309        0.252962
# 4        0.132181       -0.008205        0.531407        0.230459
#
#    mean_AAy_Hand0  mean_AAz_Hand0  mean_AJx_Hand0  mean_AJy_Hand0  \
# 0       -0.732359       -0.494693       -0.375758       -0.409868
# 1       -0.731164       -0.502557       -0.359395       -0.410097
# 2       -0.737237       -0.500526       -0.368454       -0.409167
# 3       -0.716563       -0.506432       -0.355103       -0.411043
# 4       -0.731588       -0.495452       -0.366366       -0.408611
#
#    mean_AJz_Hand0  std_w_Hand0  std_x_Hand0  std_y_Hand0  std_z_Hand0  \
# 0       -0.693223    -0.953892    -0.989748    -0.973892    -0.991389
# 1       -0.699678    -0.968373    -0.987844    -0.981509    -0.997648
# 2       -0.695299    -0.939050    -0.933250    -0.965890    -0.949062
# 3       -0.688532    -0.972896    -0.975098    -0.993502    -0.979962
# 4       -0.694874    -0.985790    -0.987599    -0.984097    -0.994033
#
#    std_AVx_Hand0  std_AVy_Hand0  std_AVz_Hand0  std_AAx_Hand0  std_AAy_Hand0  \
# 0      -0.981494      -0.993215      -0.986366      -0.984964      -0.994521
# 1      -0.982790      -0.994736      -0.990855      -0.984277      -0.993979
# 2      -0.970541      -0.977899      -0.990400      -0.975563      -0.985840
# 3      -0.966229      -0.978614      -0.986885      -0.971487      -0.975541
# 4      -0.985654      -0.992723      -0.989313      -0.990797      -0.994651
#
#    std_AAz_Hand0  std_AJx_Hand0  std_AJy_Hand0  std_AJz_Hand0
# 0      -0.982496      -0.992544      -0.997751      -0.996242
# 1      -0.989055      -0.988704      -0.997746      -0.996715
# 2      -0.988301      -0.990678      -0.995391      -0.997059
# 3      -0.982469      -0.984656      -0.992066      -0.994256
# 4      -0.987582      -0.997021      -0.998238      -0.997336

# %% [markdown]
# ### Create the model

# %%
class LSTM_all_features_properties(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.LSTM(90, 40, 1, batch_first=True)
        self.fc1 = nn.Linear(3 * 40 * 2, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 5)
          
    def forward(self, x1, x2): #, x2
        print(x1.shape)
        x1, (hn, cn) = self.rnn(x1) #, (self.h0, self.c0)
        x1 = F.tanh(x1)
        #print(x2.shape)
        x2, (hm, cm) = self.rnn(x2) # (self.h0, self.c0)
        x2 = F.tanh(x2)
        #print(x1.shape,x2.shape)
        x = torch.cat((x1, x2), 2)
        #print(x.shape)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return x
    
class LSTM_all_features_ratings(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.LSTM(90+5, 40, 1, batch_first=True)
        self.fc1 = nn.Linear(3 * 40 * 2, 20)
        self.fc2 = nn.Linear(20, 10)
        self.fc3 = nn.Linear(10, 3)
          
    def forward(self, x1, x2): #, x2
        x1, (hn, cn) = self.rnn(x1) #, (self.h0, self.c0)
        x1 = F.tanh(x1)
        x2, (hm, cm) = self.rnn(x2) # (self.h0, self.c0)
        x2 = F.tanh(x2)
        
        x = torch.cat((x1, x2), 2)
        #print(x.shape)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        #print(x.shape)
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return x

# %%
def find_best_model_for_3d_X(train_dataloader, val_dataloader, learning_rate, num_epochs, model):

    # Model
    train_model = model

    # Loss and Optimiser
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(train_model.parameters(), lr=learning_rate, momentum=0.7)

    best_avg_loss = np.inf
    best_model = None
    #best_model_epoch_num = np.inf
    train_loss_lst = []
    val_loss_lst = []
    avg_loss_lst = []

    for epoch in range(num_epochs):  # loop over the dataset multiple times

        #Set the model in training mode
        train_model.train()

        # Initialise the total training and validation loss
        epoch_train_loss = 0
        epoch_val_loss = 0
        avg_loss = 0

        #running_loss = 0.0
        for i, train_data in enumerate(train_dataloader, 0):
            #print(len(train_data))

            # get the inputs; data is a list of [input1, input2, label]
            train_input1, train_input2, train_labels = train_data #train_input2, 

            #train_labels = train_labels.type(torch.LongTensor)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            train_preds = train_model(train_input1, train_input2)  
            #print(train_labels)#

            train_loss = criterion(train_preds, train_labels)
            train_loss.backward()
            optimizer.step()

            # Update training loss
            epoch_train_loss += train_loss.item()

        # Switch off auto grad for evaluation
        with torch.no_grad():

            # Set the model in evaluation mode
            train_model.eval()

            for j, val_data in enumerate(val_dataloader, 0):
               # print(len(val_data))
            # get the inputs; data is a list of [input1, input2, label]
                val_input1, val_input2, val_labels = val_data # val_input2, 

                #val_labels = val_labels.type(torch.LongTensor)

                val_preds = train_model(val_input1, val_input2) #, val_input2

                # Update validation loss
                val_loss = criterion(val_preds, val_labels)

                epoch_val_loss += val_loss.item()
     
        avg_training_loss = epoch_train_loss / len(train_dataloader) #count_train
        avg_validation_loss = epoch_val_loss / len(val_dataloader) #count_val
        avg_loss = (avg_training_loss + avg_validation_loss) / 2
        
        train_loss_lst.append(avg_training_loss)
        val_loss_lst.append(avg_validation_loss)
        avg_loss_lst.append(avg_loss)
         
        print(f'epoch {epoch+1}: train loss = {round(avg_training_loss,3)}, val loss = {round(avg_validation_loss,3)}, average loss = {round(avg_loss,3)}')

        if avg_loss < best_avg_loss:
            best_avg_loss = avg_loss
            best_model = train_model.state_dict()

    return best_avg_loss, best_model, train_loss_lst, val_loss_lst, avg_loss_lst   #, avg_loss_lst,

# %%
# Original
def LSTM_LOP0CV(data_0, data_1, model, num_folds=5, predicting_feature='property_id', learning_rate=0.01, num_epochs=10, random_state=num): #, num_inner_folds=5
    # Set fixed random number seed
    torch.manual_seed(num)
        
    total_conf_mat = 0
    micro_f1_lst = []
    acc_lst = []
    if predicting_feature == 'property_id':
        macro_f1_lst = []
    elif predicting_feature == 'rating_level_num':
        weighted_f1_lst = [] 
        
        data0_add = create_y_train_for_2d_X(data_0, predicting_feature = 'property_id', output_as_tensor='No')
        data0_add_pd = pd.DataFrame(data0_add, columns = ['smoothness','thickness','warmth', 'flexibility', 'softness'])
        data_0 = pd.concat([data_0.reset_index(drop=True), data0_add_pd.reset_index(drop=True)], axis=1)
        data1_add = create_y_train_for_2d_X(data_1, predicting_feature = 'property_id', output_as_tensor='No')
        data1_add_pd = pd.DataFrame(data1_add, columns = ['smoothness','thickness','warmth', 'flexibility', 'softness'])
        data_1 = pd.concat([data_1.reset_index(drop=True), data1_add_pd.reset_index(drop=True)], axis=1)
    
    for participant in sorted(data_0.participant_id.unique()): # # #:lst: #
        print(f'LEAVING PARTICIPANT {participant} OUT:')
        
        # Split the data into training and testing
        training_data_0 = data_0[data_0.participant_id != participant] 
        training_data_1 = data_1[data_1.participant_id != participant] 
        testing_data_0 = data_0[data_0.participant_id == participant] 
        testing_data_1 = data_1[data_1.participant_id == participant] 

        # Data preparation
        X_train_0 = create_X_3d(training_data_0, 12)
        X_train_1 = create_X_3d(training_data_1, 12) 
        X_test_0 = create_X_3d(testing_data_0, 12) 
        X_test_1 = create_X_3d(testing_data_1, 12)           
        y_train = create_y_train_for_3d_X(training_data_0, predicting_feature = predicting_feature)
        y_test = create_y_test_for_3d_X(testing_data_0, predicting_feature = predicting_feature)        
 

        #print(X_train_0.shape)
        #print(X_train_1.shape)
        #print(y_train.shape)
        #print(X_test_0.shape)
        #print(X_test_1.shape)
        #print(y_test.shape)
 
        # Create the datasets and dataloaders
        train_dataset = TensorDataset(X_train_0, X_train_1, y_train) 
        
        test_dataset = TensorDataset(X_test_0, X_test_1, y_test)
        test_dataloader = torch.utils.data.DataLoader(test_dataset, shuffle=True, batch_size=y_test.shape[0]//4) # num_workers=2,       
            
        # Configure the cross-validation procedure
        cv_inner = KFold(n_splits=num_folds, shuffle=True, random_state=num)
                
        min_avg_loss_subject = np.inf
        best_model_subject = None
        
        best_train_loss_lst = None
        best_val_loss_lst = None
        best_avg_loss_lst = None
        best_fold = np.inf

        for fold, (train_ids, val_ids) in enumerate(cv_inner.split(train_dataset)):
            print(f'FOLD {fold+1}:')
                       
            # Sample elements randomly from a given list of ids, no replacement.
            train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids) # The ids are the same for both
            val_subsampler = torch.utils.data.SubsetRandomSampler(val_ids)

            # Define data loaders for training and testing data in this fold
            train_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=train_subsampler) #, batch_size=100
            val_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=val_subsampler) #, batch_size=20        

            avg_loss_fold, best_model_fold, fold_train_loss_lst, fold_val_loss_lst, fold_avg_loss_lst = find_best_model_for_3d_X(train_dataloader, val_dataloader, learning_rate, num_epochs, model)
                           
            if avg_loss_fold < min_avg_loss_subject:
                min_avg_loss_subject = avg_loss_fold
                best_model_subject = best_model_fold
                best_train_loss_lst = fold_train_loss_lst
                best_val_loss_lst = fold_val_loss_lst
                best_avg_loss_lst = fold_avg_loss_lst
                best_fold = fold+1

        fig = plt.figure(f"{participant}")                  
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_train_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_val_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_avg_loss_lst)
        plt.title(f"Loss when participant {participant} is left out for fold {best_fold} (lr={learning_rate}, num_epochs ={num_epochs})")
        plt.legend(['train loss', 'val loss', 'avg_loss'])

        # save trained model 
        name = 'model_participant_'+str(participant)+'.pt'
        torch.save(best_model_subject, name)
        print(f'The model for participant {participant} has been saved')
        
        test_model = model
        test_model.load_state_dict(torch.load(name))

        dataiter = iter(test_dataloader) 
        test_input1, test_input2, test_labels = dataiter.next() 
    
        test_preds = test_model(test_input1, test_input2) 
        
        test_preds_np = test_preds.detach().numpy()
        test_predicted_np = np.argmax(test_preds_np, axis = 1)
        
        test_labels_np = test_labels.numpy()    
        
        if predicting_feature == 'property_id':
            conf_mat = confusion_matrix(test_labels_np, test_predicted_np, labels=[0, 1, 2, 3, 4])
            macro_f1_score = f1_score(test_labels_np, test_predicted_np, average='macro') 
            macro_f1_lst.append(macro_f1_score) 
        elif predicting_feature == 'rating_level_num':
            conf_mat = confusion_matrix(test_labels_np, test_predicted_np, labels=[0,1,2])
            weighted_f1_score = f1_score(test_labels_np, test_predicted_np, average='weighted') 
            weighted_f1_lst.append(weighted_f1_score)
            
        total_conf_mat += conf_mat
        micro_f1_score = f1_score(test_labels_np, test_predicted_np, average='micro')  
        micro_f1_lst.append(micro_f1_score)
        acc = accuracy_score(test_labels_np, test_predicted_np)
        acc_lst.append(acc)


        print(f"Leaving participant {participant} out")
        print("(1) Confusion matrix:\n", conf_mat)
        print(f"(2) micro F1 score = {round(micro_f1_score,2)}")
        if predicting_feature == 'property_id':
            print(f"(3) Macro F1 score = {round(macro_f1_score,2)}")
        elif predicting_feature == 'rating_level_num':
            print(f"(3) Weighted F1 score = {round(weighted_f1_score,2)}")            
        print(f"(4) Percentage Classification accuracy = {round(acc*100,2)}%")
        
        total_conf_mat += conf_mat 
        micro_f1_lst.append(micro_f1_score)
        acc_lst.append(acc)
        print('--------------------------------')
        
    avg_micro_f1_score = sum(micro_f1_lst) / len(micro_f1_lst)
    if predicting_feature == 'property_id':
        avg_macro_f1_score = sum(macro_f1_lst) / len(macro_f1_lst)  
    elif predicting_feature == 'rating_level_num':
        avg_weighted_f1_score = sum(weighted_f1_lst) / len(weighted_f1_lst)             
    avg_acc = sum(acc_lst) / len(acc_lst)   
    
    print(f'Using Leave One Participant Out CV (LOPOCV):') 
    print("(1) Confusion matrix:\n", total_conf_mat)
    print(f"(2) Average micro F1 score = {round(avg_micro_f1_score,2)}")
    if predicting_feature == 'property_id':
        print(f"(3) Average macro F1 score = {round(avg_macro_f1_score,2)}")
    elif predicting_feature == 'rating_level_num':
        print(f"(3) Average weighted F1 score = {round(avg_weighted_f1_score,2)}")      
    print(f"(4) Average Percentage Classification accuracy = {round(avg_acc*100,2)}%")

# %% [markdown]
# ### Run the model for properties

# %%
#LSTM_LOP0CV(hand_0, hand_1, model=LSTM_all_features_properties(), num_folds=5, predicting_feature='property_id', learning_rate=0.005, num_epochs=50, random_state=num) #, num_inner_folds=5

# %% [markdown]
# ### Run the model for ratings

# %%
LSTM_LOP0CV(hand_0, hand_1, model=LSTM_all_features_ratings(), num_folds=5, predicting_feature='rating_level_num', learning_rate=0.005, num_epochs=50, random_state=num) #, num_inner_folds=5
# Out:
# LEAVING PARTICIPANT 1 OUT:
# FOLD 1:
# epoch 1: train loss = 1.092, val loss = 1.048, average loss = 1.07
# epoch 2: train loss = 1.058, val loss = 1.009, average loss = 1.034
# epoch 3: train loss = 1.048, val loss = 0.994, average loss = 1.021
# epoch 4: train loss = 1.045, val loss = 0.991, average loss = 1.018
# epoch 5: train loss = 1.045, val loss = 0.99, average loss = 1.017
# epoch 6: train loss = 1.044, val loss = 0.989, average loss = 1.017
# epoch 7: train loss = 1.044, val loss = 0.987, average loss = 1.016
# epoch 8: train loss = 1.044, val loss = 0.987, average loss = 1.016
# epoch 9: train loss = 1.044, val loss = 0.987, average loss = 1.015
# epoch 10: train loss = 1.044, val loss = 0.986, average loss = 1.015
# epoch 11: train loss = 1.044, val loss = 0.986, average loss = 1.015
# epoch 12: train loss = 1.044, val loss = 0.986, average loss = 1.015
# epoch 13: train loss = 1.044, val loss = 0.985, average loss = 1.014
# epoch 14: train loss = 1.043, val loss = 0.985, average loss = 1.014
# epoch 15: train loss = 1.043, val loss = 0.986, average loss = 1.015
# epoch 16: train loss = 1.043, val loss = 0.987, average loss = 1.015
# epoch 17: train loss = 1.042, val loss = 0.986, average loss = 1.014
# epoch 18: train loss = 1.041, val loss = 0.983, average loss = 1.012
# epoch 19: train loss = 1.041, val loss = 0.982, average loss = 1.011
# epoch 20: train loss = 1.04, val loss = 0.983, average loss = 1.012
# epoch 21: train loss = 1.038, val loss = 0.986, average loss = 1.012
# epoch 22: train loss = 1.035, val loss = 0.992, average loss = 1.014
# epoch 23: train loss = 1.032, val loss = 0.981, average loss = 1.006
# epoch 24: train loss = 1.029, val loss = 0.982, average loss = 1.006
# epoch 25: train loss = 1.025, val loss = 1.0, average loss = 1.012
# epoch 26: train loss = 1.019, val loss = 0.984, average loss = 1.002
# epoch 27: train loss = 1.013, val loss = 0.974, average loss = 0.993
# epoch 28: train loss = 1.016, val loss = 1.016, average loss = 1.016
# epoch 29: train loss = 1.009, val loss = 0.981, average loss = 0.995
# epoch 30: train loss = 1.005, val loss = 0.993, average loss = 0.999
# epoch 31: train loss = 0.998, val loss = 0.97, average loss = 0.984
# epoch 32: train loss = 1.005, val loss = 0.968, average loss = 0.987
# epoch 33: train loss = 0.986, val loss = 0.976, average loss = 0.981
# epoch 34: train loss = 0.994, val loss = 0.971, average loss = 0.982
# epoch 35: train loss = 0.988, val loss = 0.987, average loss = 0.987
# epoch 36: train loss = 0.988, val loss = 0.969, average loss = 0.978
# epoch 37: train loss = 0.976, val loss = 0.98, average loss = 0.978
# epoch 38: train loss = 0.975, val loss = 1.057, average loss = 1.016
# epoch 39: train loss = 0.996, val loss = 0.965, average loss = 0.981
# epoch 40: train loss = 0.977, val loss = 0.979, average loss = 0.978
# epoch 41: train loss = 0.979, val loss = 0.966, average loss = 0.973
# epoch 42: train loss = 0.978, val loss = 1.035, average loss = 1.007
# epoch 43: train loss = 0.987, val loss = 0.973, average loss = 0.98
# epoch 44: train loss = 0.974, val loss = 1.021, average loss = 0.997
# epoch 45: train loss = 0.966, val loss = 0.971, average loss = 0.968
# epoch 46: train loss = 0.96, val loss = 0.979, average loss = 0.97
# epoch 47: train loss = 0.958, val loss = 0.977, average loss = 0.968
# epoch 48: train loss = 0.968, val loss = 0.974, average loss = 0.971
# epoch 49: train loss = 0.964, val loss = 0.992, average loss = 0.978
# epoch 50: train loss = 0.967, val loss = 1.014, average loss = 0.99
# FOLD 2:
# epoch 1: train loss = 0.963, val loss = 1.0, average loss = 0.981
# epoch 2: train loss = 0.959, val loss = 1.02, average loss = 0.99
# epoch 3: train loss = 0.953, val loss = 1.031, average loss = 0.992
# epoch 4: train loss = 0.961, val loss = 1.022, average loss = 0.991
# epoch 5: train loss = 0.947, val loss = 1.062, average loss = 1.005
# epoch 6: train loss = 0.971, val loss = 1.032, average loss = 1.001
# epoch 7: train loss = 0.951, val loss = 1.11, average loss = 1.03
# epoch 8: train loss = 0.955, val loss = 1.013, average loss = 0.984
# epoch 9: train loss = 0.947, val loss = 1.007, average loss = 0.977
# epoch 10: train loss = 0.951, val loss = 1.015, average loss = 0.983
# epoch 11: train loss = 0.957, val loss = 1.063, average loss = 1.01
# epoch 12: train loss = 0.97, val loss = 1.024, average loss = 0.997
# epoch 13: train loss = 0.943, val loss = 1.087, average loss = 1.015
# epoch 14: train loss = 0.947, val loss = 1.063, average loss = 1.005
# epoch 15: train loss = 0.941, val loss = 1.042, average loss = 0.991
# epoch 16: train loss = 0.947, val loss = 1.02, average loss = 0.984
# epoch 17: train loss = 0.949, val loss = 1.036, average loss = 0.993
# epoch 18: train loss = 0.957, val loss = 1.035, average loss = 0.996
# epoch 19: train loss = 0.942, val loss = 1.05, average loss = 0.996
# epoch 20: train loss = 0.96, val loss = 1.031, average loss = 0.995
# epoch 21: train loss = 0.936, val loss = 1.015, average loss = 0.976
# epoch 22: train loss = 0.924, val loss = 1.015, average loss = 0.97
# epoch 23: train loss = 0.923, val loss = 1.068, average loss = 0.996
# epoch 24: train loss = 0.936, val loss = 1.063, average loss = 0.999
# epoch 25: train loss = 0.928, val loss = 1.099, average loss = 1.013
# epoch 26: train loss = 0.926, val loss = 1.019, average loss = 0.973
# epoch 27: train loss = 0.923, val loss = 1.075, average loss = 0.999
# epoch 28: train loss = 0.929, val loss = 1.053, average loss = 0.991
# epoch 29: train loss = 0.926, val loss = 1.019, average loss = 0.973
# epoch 30: train loss = 0.913, val loss = 1.045, average loss = 0.979
# epoch 31: train loss = 0.928, val loss = 1.078, average loss = 1.003
# epoch 32: train loss = 0.929, val loss = 1.098, average loss = 1.013
# epoch 33: train loss = 0.918, val loss = 1.059, average loss = 0.988
# epoch 34: train loss = 0.923, val loss = 1.097, average loss = 1.01
# epoch 35: train loss = 0.945, val loss = 1.071, average loss = 1.008
# epoch 36: train loss = 0.93, val loss = 1.052, average loss = 0.991
# epoch 37: train loss = 0.911, val loss = 1.049, average loss = 0.98
# epoch 38: train loss = 0.931, val loss = 1.048, average loss = 0.99
# epoch 39: train loss = 0.934, val loss = 1.059, average loss = 0.996
# epoch 40: train loss = 0.902, val loss = 1.051, average loss = 0.977
# epoch 41: train loss = 0.919, val loss = 1.054, average loss = 0.987
# epoch 42: train loss = 0.944, val loss = 1.06, average loss = 1.002
# epoch 43: train loss = 0.908, val loss = 1.073, average loss = 0.99
# epoch 44: train loss = 0.9, val loss = 1.071, average loss = 0.985
# epoch 45: train loss = 0.93, val loss = 1.065, average loss = 0.997
# epoch 46: train loss = 0.897, val loss = 1.04, average loss = 0.968
# epoch 47: train loss = 0.898, val loss = 1.055, average loss = 0.977
# epoch 48: train loss = 0.913, val loss = 1.053, average loss = 0.983
# epoch 49: train loss = 0.911, val loss = 1.088, average loss = 1.0
# epoch 50: train loss = 0.901, val loss = 1.04, average loss = 0.971
# FOLD 3:
# epoch 1: train loss = 0.941, val loss = 0.92, average loss = 0.931
# epoch 2: train loss = 0.947, val loss = 0.923, average loss = 0.935
# epoch 3: train loss = 0.945, val loss = 0.923, average loss = 0.934
# epoch 4: train loss = 0.934, val loss = 0.923, average loss = 0.928
# epoch 5: train loss = 0.92, val loss = 0.929, average loss = 0.924
# epoch 6: train loss = 0.934, val loss = 0.919, average loss = 0.927
# epoch 7: train loss = 0.918, val loss = 0.929, average loss = 0.923
# epoch 8: train loss = 0.922, val loss = 0.922, average loss = 0.922
# epoch 9: train loss = 0.912, val loss = 0.913, average loss = 0.913
# epoch 10: train loss = 0.919, val loss = 0.949, average loss = 0.934
# epoch 11: train loss = 0.911, val loss = 0.978, average loss = 0.945
# epoch 12: train loss = 0.924, val loss = 0.927, average loss = 0.925
# epoch 13: train loss = 0.92, val loss = 0.929, average loss = 0.924
# epoch 14: train loss = 0.914, val loss = 0.916, average loss = 0.915
# epoch 15: train loss = 0.906, val loss = 0.923, average loss = 0.915
# epoch 16: train loss = 0.918, val loss = 0.934, average loss = 0.926
# epoch 17: train loss = 0.911, val loss = 0.925, average loss = 0.918
# epoch 18: train loss = 0.903, val loss = 0.925, average loss = 0.914
# epoch 19: train loss = 0.901, val loss = 0.957, average loss = 0.929
# epoch 20: train loss = 0.927, val loss = 0.908, average loss = 0.918
# epoch 21: train loss = 0.9, val loss = 0.895, average loss = 0.898
# epoch 22: train loss = 0.907, val loss = 0.995, average loss = 0.951
# epoch 23: train loss = 0.906, val loss = 0.902, average loss = 0.904
# epoch 24: train loss = 0.907, val loss = 0.951, average loss = 0.929
# epoch 25: train loss = 0.953, val loss = 1.193, average loss = 1.073
# epoch 26: train loss = 0.945, val loss = 0.991, average loss = 0.968
# epoch 27: train loss = 0.956, val loss = 1.013, average loss = 0.984
# epoch 28: train loss = 0.942, val loss = 0.983, average loss = 0.962
# epoch 29: train loss = 0.918, val loss = 0.963, average loss = 0.941
# epoch 30: train loss = 0.926, val loss = 0.938, average loss = 0.932
# epoch 31: train loss = 0.915, val loss = 0.961, average loss = 0.938
# epoch 32: train loss = 0.913, val loss = 0.959, average loss = 0.936
# epoch 33: train loss = 0.897, val loss = 0.941, average loss = 0.919
# epoch 34: train loss = 0.918, val loss = 0.963, average loss = 0.941
# epoch 35: train loss = 0.912, val loss = 0.992, average loss = 0.952
# epoch 36: train loss = 0.901, val loss = 0.927, average loss = 0.914
# epoch 37: train loss = 0.892, val loss = 0.951, average loss = 0.921
# epoch 38: train loss = 0.937, val loss = 0.994, average loss = 0.965
# epoch 39: train loss = 0.929, val loss = 0.961, average loss = 0.945
# epoch 40: train loss = 0.889, val loss = 0.973, average loss = 0.931
# epoch 41: train loss = 0.894, val loss = 0.976, average loss = 0.935
# epoch 42: train loss = 0.928, val loss = 0.986, average loss = 0.957
# epoch 43: train loss = 0.912, val loss = 0.937, average loss = 0.925
# epoch 44: train loss = 0.882, val loss = 0.978, average loss = 0.93
# epoch 45: train loss = 0.919, val loss = 0.964, average loss = 0.942
# epoch 46: train loss = 0.895, val loss = 0.951, average loss = 0.923
# epoch 47: train loss = 0.886, val loss = 0.958, average loss = 0.922
# epoch 48: train loss = 0.887, val loss = 0.944, average loss = 0.916
# epoch 49: train loss = 0.958, val loss = 0.959, average loss = 0.958
# epoch 50: train loss = 0.909, val loss = 0.954, average loss = 0.931
# FOLD 4:
# epoch 1: train loss = 0.925, val loss = 0.954, average loss = 0.939
# epoch 2: train loss = 0.899, val loss = 0.872, average loss = 0.885
# epoch 3: train loss = 0.915, val loss = 0.836, average loss = 0.875
# epoch 4: train loss = 0.907, val loss = 0.854, average loss = 0.881
# epoch 5: train loss = 0.945, val loss = 0.898, average loss = 0.922
# epoch 6: train loss = 0.909, val loss = 0.942, average loss = 0.925
# epoch 7: train loss = 0.924, val loss = 0.871, average loss = 0.897
# epoch 8: train loss = 0.909, val loss = 0.994, average loss = 0.951
# epoch 9: train loss = 0.921, val loss = 0.963, average loss = 0.942
# epoch 10: train loss = 0.905, val loss = 0.979, average loss = 0.942
# epoch 11: train loss = 0.91, val loss = 0.923, average loss = 0.916
# epoch 12: train loss = 0.901, val loss = 0.83, average loss = 0.866
# epoch 13: train loss = 0.903, val loss = 0.917, average loss = 0.91
# epoch 14: train loss = 0.898, val loss = 0.922, average loss = 0.91
# epoch 15: train loss = 0.898, val loss = 0.952, average loss = 0.925
# epoch 16: train loss = 0.883, val loss = 0.852, average loss = 0.867
# epoch 17: train loss = 0.897, val loss = 0.855, average loss = 0.876
# epoch 18: train loss = 0.894, val loss = 0.924, average loss = 0.909
# epoch 19: train loss = 0.894, val loss = 0.898, average loss = 0.896
# epoch 20: train loss = 0.864, val loss = 0.921, average loss = 0.892
# epoch 21: train loss = 0.867, val loss = 0.911, average loss = 0.889
# epoch 22: train loss = 0.86, val loss = 0.96, average loss = 0.91
# epoch 23: train loss = 0.896, val loss = 0.931, average loss = 0.914
# epoch 24: train loss = 0.855, val loss = 0.91, average loss = 0.883
# epoch 25: train loss = 0.878, val loss = 0.899, average loss = 0.889
# epoch 26: train loss = 0.859, val loss = 1.0, average loss = 0.929
# epoch 27: train loss = 0.872, val loss = 0.967, average loss = 0.92
# epoch 28: train loss = 0.874, val loss = 0.989, average loss = 0.931
# epoch 29: train loss = 0.882, val loss = 0.963, average loss = 0.923
# epoch 30: train loss = 0.889, val loss = 0.944, average loss = 0.917
# epoch 31: train loss = 0.862, val loss = 0.871, average loss = 0.866
# epoch 32: train loss = 0.85, val loss = 0.968, average loss = 0.909
# epoch 33: train loss = 0.885, val loss = 0.968, average loss = 0.926
# epoch 34: train loss = 0.87, val loss = 0.99, average loss = 0.93
# epoch 35: train loss = 0.889, val loss = 0.953, average loss = 0.921
# epoch 36: train loss = 0.883, val loss = 1.059, average loss = 0.971
# epoch 37: train loss = 0.89, val loss = 1.061, average loss = 0.976
# epoch 38: train loss = 0.86, val loss = 0.929, average loss = 0.894
# epoch 39: train loss = 0.88, val loss = 1.088, average loss = 0.984
# epoch 40: train loss = 0.883, val loss = 1.188, average loss = 1.036
# epoch 41: train loss = 0.881, val loss = 1.016, average loss = 0.949
# epoch 42: train loss = 0.844, val loss = 0.922, average loss = 0.883
# epoch 43: train loss = 0.866, val loss = 0.965, average loss = 0.916
# epoch 44: train loss = 0.855, val loss = 1.032, average loss = 0.944
# epoch 45: train loss = 0.847, val loss = 0.929, average loss = 0.888
# epoch 46: train loss = 0.858, val loss = 0.943, average loss = 0.901
# epoch 47: train loss = 0.827, val loss = 0.922, average loss = 0.874
# epoch 48: train loss = 0.825, val loss = 1.04, average loss = 0.932
# epoch 49: train loss = 0.858, val loss = 0.983, average loss = 0.92
# epoch 50: train loss = 0.826, val loss = 0.971, average loss = 0.898
# FOLD 5:
# epoch 1: train loss = 0.883, val loss = 0.852, average loss = 0.868
# epoch 2: train loss = 0.882, val loss = 0.838, average loss = 0.86
# epoch 3: train loss = 0.905, val loss = 0.814, average loss = 0.859
# epoch 4: train loss = 0.877, val loss = 0.889, average loss = 0.883
# epoch 5: train loss = 0.917, val loss = 0.877, average loss = 0.897
# epoch 6: train loss = 0.892, val loss = 0.851, average loss = 0.871
# epoch 7: train loss = 0.869, val loss = 0.825, average loss = 0.847
# epoch 8: train loss = 0.875, val loss = 1.033, average loss = 0.954
# epoch 9: train loss = 0.863, val loss = 0.86, average loss = 0.862
# epoch 10: train loss = 0.884, val loss = 0.856, average loss = 0.87
# epoch 11: train loss = 0.853, val loss = 0.867, average loss = 0.86
# epoch 12: train loss = 0.857, val loss = 0.828, average loss = 0.842
# epoch 13: train loss = 0.851, val loss = 0.91, average loss = 0.881
# epoch 14: train loss = 0.894, val loss = 0.932, average loss = 0.913
# epoch 15: train loss = 0.886, val loss = 0.859, average loss = 0.873
# epoch 16: train loss = 0.881, val loss = 0.853, average loss = 0.867
# epoch 17: train loss = 0.862, val loss = 0.862, average loss = 0.862
# epoch 18: train loss = 0.828, val loss = 0.957, average loss = 0.892
# epoch 19: train loss = 0.946, val loss = 0.842, average loss = 0.894
# epoch 20: train loss = 0.858, val loss = 0.856, average loss = 0.857
# epoch 21: train loss = 0.855, val loss = 0.859, average loss = 0.857
# epoch 22: train loss = 0.872, val loss = 0.828, average loss = 0.85
# epoch 23: train loss = 0.86, val loss = 0.853, average loss = 0.856
# epoch 24: train loss = 0.873, val loss = 0.852, average loss = 0.863
# epoch 25: train loss = 0.822, val loss = 0.869, average loss = 0.845
# epoch 26: train loss = 0.828, val loss = 0.866, average loss = 0.847
# epoch 27: train loss = 0.848, val loss = 0.924, average loss = 0.886
# epoch 28: train loss = 0.803, val loss = 0.927, average loss = 0.865
# epoch 29: train loss = 0.823, val loss = 0.832, average loss = 0.827
# epoch 30: train loss = 0.82, val loss = 0.826, average loss = 0.823
# epoch 31: train loss = 0.832, val loss = 0.819, average loss = 0.825
# epoch 32: train loss = 0.828, val loss = 0.847, average loss = 0.838
# epoch 33: train loss = 0.827, val loss = 0.831, average loss = 0.829
# epoch 34: train loss = 0.826, val loss = 0.929, average loss = 0.877
# epoch 35: train loss = 0.815, val loss = 0.918, average loss = 0.866
# epoch 36: train loss = 0.832, val loss = 0.868, average loss = 0.85
# epoch 37: train loss = 0.824, val loss = 0.87, average loss = 0.847
# epoch 38: train loss = 0.811, val loss = 0.913, average loss = 0.862
# epoch 39: train loss = 0.836, val loss = 0.904, average loss = 0.87
# epoch 40: train loss = 0.823, val loss = 0.874, average loss = 0.849
# epoch 41: train loss = 0.825, val loss = 0.821, average loss = 0.823
# epoch 42: train loss = 0.809, val loss = 0.889, average loss = 0.849
# epoch 43: train loss = 0.818, val loss = 0.839, average loss = 0.828
# epoch 44: train loss = 0.804, val loss = 0.874, average loss = 0.839
# epoch 45: train loss = 0.78, val loss = 0.887, average loss = 0.833
# epoch 46: train loss = 0.797, val loss = 0.841, average loss = 0.819
# epoch 47: train loss = 0.796, val loss = 0.949, average loss = 0.872
# epoch 48: train loss = 0.823, val loss = 0.91, average loss = 0.867
# epoch 49: train loss = 0.815, val loss = 0.893, average loss = 0.854
# epoch 50: train loss = 0.817, val loss = 0.84, average loss = 0.828
# The model for participant 1 has been saved
# Leaving participant 1 out
# (1) Confusion matrix:
#  [[0 3 0]
#  [1 3 0]
#  [0 0 0]]
# (2) micro F1 score = 0.43
# (3) Weighted F1 score = 0.34
# (4) Percentage Classification accuracy = 42.86%
# --------------------------------
# LEAVING PARTICIPANT 2 OUT:
# FOLD 1:
# epoch 1: train loss = 0.912, val loss = 0.813, average loss = 0.862
# epoch 2: train loss = 0.842, val loss = 0.778, average loss = 0.81
# epoch 3: train loss = 0.848, val loss = 0.796, average loss = 0.822
# epoch 4: train loss = 0.842, val loss = 0.79, average loss = 0.816
# epoch 5: train loss = 0.834, val loss = 0.804, average loss = 0.819
# epoch 6: train loss = 0.838, val loss = 0.801, average loss = 0.82
# epoch 7: train loss = 0.873, val loss = 0.833, average loss = 0.853
# epoch 8: train loss = 0.83, val loss = 0.825, average loss = 0.828
# epoch 9: train loss = 0.836, val loss = 0.836, average loss = 0.836
# epoch 10: train loss = 0.855, val loss = 0.796, average loss = 0.826
# epoch 11: train loss = 0.822, val loss = 0.811, average loss = 0.816
# epoch 12: train loss = 0.834, val loss = 0.775, average loss = 0.804
# epoch 13: train loss = 0.849, val loss = 0.797, average loss = 0.823
# epoch 14: train loss = 0.833, val loss = 0.805, average loss = 0.819
# epoch 15: train loss = 0.879, val loss = 0.783, average loss = 0.831
# epoch 16: train loss = 0.873, val loss = 0.835, average loss = 0.854
# epoch 17: train loss = 0.849, val loss = 0.793, average loss = 0.821
# epoch 18: train loss = 0.839, val loss = 0.819, average loss = 0.829
# epoch 19: train loss = 0.825, val loss = 0.828, average loss = 0.827
# epoch 20: train loss = 0.846, val loss = 0.818, average loss = 0.832
# epoch 21: train loss = 0.817, val loss = 0.812, average loss = 0.815
# epoch 22: train loss = 0.829, val loss = 0.824, average loss = 0.827
# epoch 23: train loss = 0.852, val loss = 0.807, average loss = 0.83
# epoch 24: train loss = 0.853, val loss = 0.869, average loss = 0.861
# epoch 25: train loss = 0.826, val loss = 0.825, average loss = 0.826
# epoch 26: train loss = 0.81, val loss = 0.809, average loss = 0.81
# epoch 27: train loss = 0.834, val loss = 0.804, average loss = 0.819
# epoch 28: train loss = 0.815, val loss = 0.803, average loss = 0.809
# epoch 29: train loss = 0.807, val loss = 0.814, average loss = 0.81
# epoch 30: train loss = 0.856, val loss = 0.883, average loss = 0.87
# epoch 31: train loss = 0.834, val loss = 0.834, average loss = 0.834
# epoch 32: train loss = 0.826, val loss = 0.805, average loss = 0.816
# epoch 33: train loss = 0.824, val loss = 0.892, average loss = 0.858
# epoch 34: train loss = 0.805, val loss = 0.86, average loss = 0.833
# epoch 35: train loss = 0.849, val loss = 0.819, average loss = 0.834
# epoch 36: train loss = 0.81, val loss = 0.829, average loss = 0.819
# epoch 37: train loss = 0.825, val loss = 0.829, average loss = 0.827
# epoch 38: train loss = 0.805, val loss = 0.847, average loss = 0.826
# epoch 39: train loss = 0.82, val loss = 0.834, average loss = 0.827
# epoch 40: train loss = 0.802, val loss = 0.842, average loss = 0.822
# epoch 41: train loss = 0.797, val loss = 0.831, average loss = 0.814
# epoch 42: train loss = 0.823, val loss = 0.852, average loss = 0.838
# epoch 43: train loss = 0.791, val loss = 0.866, average loss = 0.829
# epoch 44: train loss = 0.818, val loss = 0.825, average loss = 0.821
# epoch 45: train loss = 0.807, val loss = 0.922, average loss = 0.864
# epoch 46: train loss = 0.815, val loss = 0.857, average loss = 0.836
# epoch 47: train loss = 0.788, val loss = 0.868, average loss = 0.828
# epoch 48: train loss = 0.779, val loss = 0.855, average loss = 0.817
# epoch 49: train loss = 0.794, val loss = 0.843, average loss = 0.818
# epoch 50: train loss = 0.789, val loss = 0.829, average loss = 0.809
# FOLD 2:
# epoch 1: train loss = 0.837, val loss = 0.856, average loss = 0.847
# epoch 2: train loss = 0.808, val loss = 0.867, average loss = 0.837
# epoch 3: train loss = 0.819, val loss = 0.874, average loss = 0.847
# epoch 4: train loss = 0.797, val loss = 0.848, average loss = 0.823
# epoch 5: train loss = 0.848, val loss = 0.861, average loss = 0.855
# epoch 6: train loss = 0.795, val loss = 0.8, average loss = 0.797
# epoch 7: train loss = 0.8, val loss = 0.8, average loss = 0.8
# epoch 8: train loss = 0.806, val loss = 0.821, average loss = 0.814
# epoch 9: train loss = 0.808, val loss = 0.88, average loss = 0.844
# epoch 10: train loss = 0.782, val loss = 0.807, average loss = 0.795
# epoch 11: train loss = 0.777, val loss = 0.805, average loss = 0.791
# epoch 12: train loss = 0.8, val loss = 0.859, average loss = 0.83
# epoch 13: train loss = 0.822, val loss = 0.917, average loss = 0.869
# epoch 14: train loss = 0.816, val loss = 0.863, average loss = 0.839
# epoch 15: train loss = 0.804, val loss = 0.843, average loss = 0.824
# epoch 16: train loss = 0.788, val loss = 0.843, average loss = 0.816
# epoch 17: train loss = 0.809, val loss = 0.859, average loss = 0.834
# epoch 18: train loss = 0.781, val loss = 0.851, average loss = 0.816
# epoch 19: train loss = 0.786, val loss = 0.815, average loss = 0.8
# epoch 20: train loss = 0.765, val loss = 0.838, average loss = 0.802
# epoch 21: train loss = 0.77, val loss = 0.854, average loss = 0.812
# epoch 22: train loss = 0.761, val loss = 0.848, average loss = 0.804
# epoch 23: train loss = 0.766, val loss = 0.822, average loss = 0.794
# epoch 24: train loss = 0.753, val loss = 0.866, average loss = 0.809
# epoch 25: train loss = 0.739, val loss = 0.868, average loss = 0.804
# epoch 26: train loss = 0.753, val loss = 0.862, average loss = 0.807
# epoch 27: train loss = 0.776, val loss = 0.832, average loss = 0.804
# epoch 28: train loss = 0.769, val loss = 0.817, average loss = 0.793
# epoch 29: train loss = 0.757, val loss = 0.87, average loss = 0.813
# epoch 30: train loss = 0.759, val loss = 0.871, average loss = 0.815
# epoch 31: train loss = 0.752, val loss = 0.859, average loss = 0.805
# epoch 32: train loss = 0.754, val loss = 0.857, average loss = 0.806
# epoch 33: train loss = 0.739, val loss = 0.861, average loss = 0.8
# epoch 34: train loss = 0.738, val loss = 0.865, average loss = 0.802
# epoch 35: train loss = 0.736, val loss = 0.873, average loss = 0.805
# epoch 36: train loss = 0.774, val loss = 0.914, average loss = 0.844
# epoch 37: train loss = 0.752, val loss = 0.852, average loss = 0.802
# epoch 38: train loss = 0.748, val loss = 0.893, average loss = 0.82
# epoch 39: train loss = 0.747, val loss = 0.862, average loss = 0.804
# epoch 40: train loss = 0.752, val loss = 0.821, average loss = 0.786
# epoch 41: train loss = 0.745, val loss = 0.858, average loss = 0.802
# epoch 42: train loss = 0.772, val loss = 0.889, average loss = 0.83
# epoch 43: train loss = 0.746, val loss = 0.876, average loss = 0.811
# epoch 44: train loss = 0.734, val loss = 0.864, average loss = 0.799
# epoch 45: train loss = 0.742, val loss = 0.866, average loss = 0.804
# epoch 46: train loss = 0.741, val loss = 0.868, average loss = 0.804
# epoch 47: train loss = 0.737, val loss = 0.868, average loss = 0.803
# epoch 48: train loss = 0.739, val loss = 0.866, average loss = 0.802
# epoch 49: train loss = 0.737, val loss = 0.862, average loss = 0.8
# epoch 50: train loss = 0.749, val loss = 0.842, average loss = 0.795
# FOLD 3:
# epoch 1: train loss = 0.797, val loss = 0.747, average loss = 0.772
# epoch 2: train loss = 0.779, val loss = 0.782, average loss = 0.78
# epoch 3: train loss = 0.768, val loss = 0.758, average loss = 0.763
# epoch 4: train loss = 0.796, val loss = 0.755, average loss = 0.776
# epoch 5: train loss = 0.756, val loss = 0.799, average loss = 0.778
# epoch 6: train loss = 0.791, val loss = 0.791, average loss = 0.791
# epoch 7: train loss = 0.75, val loss = 0.796, average loss = 0.773
# epoch 8: train loss = 0.794, val loss = 0.875, average loss = 0.835
# epoch 9: train loss = 0.786, val loss = 0.837, average loss = 0.812
# epoch 10: train loss = 0.829, val loss = 0.909, average loss = 0.869
# epoch 11: train loss = 0.828, val loss = 0.869, average loss = 0.849
# epoch 12: train loss = 0.802, val loss = 0.863, average loss = 0.832
# epoch 13: train loss = 0.776, val loss = 0.826, average loss = 0.801
# epoch 14: train loss = 0.782, val loss = 0.809, average loss = 0.795
# epoch 15: train loss = 0.765, val loss = 0.845, average loss = 0.805
# epoch 16: train loss = 0.803, val loss = 0.807, average loss = 0.805
# epoch 17: train loss = 0.764, val loss = 0.788, average loss = 0.776
# epoch 18: train loss = 0.766, val loss = 0.884, average loss = 0.825
# epoch 19: train loss = 0.819, val loss = 0.845, average loss = 0.832
# epoch 20: train loss = 0.764, val loss = 0.808, average loss = 0.786
# epoch 21: train loss = 0.762, val loss = 0.855, average loss = 0.809
# epoch 22: train loss = 0.747, val loss = 0.854, average loss = 0.8
# epoch 23: train loss = 0.745, val loss = 0.839, average loss = 0.792
# epoch 24: train loss = 0.761, val loss = 0.808, average loss = 0.784
# epoch 25: train loss = 0.738, val loss = 0.815, average loss = 0.777
# epoch 26: train loss = 0.749, val loss = 0.776, average loss = 0.763
# epoch 27: train loss = 0.761, val loss = 0.839, average loss = 0.8
# epoch 28: train loss = 0.753, val loss = 0.885, average loss = 0.819
# epoch 29: train loss = 0.736, val loss = 0.82, average loss = 0.778
# epoch 30: train loss = 0.764, val loss = 0.83, average loss = 0.797
# epoch 31: train loss = 0.752, val loss = 0.848, average loss = 0.8
# epoch 32: train loss = 0.746, val loss = 0.843, average loss = 0.794
# epoch 33: train loss = 0.727, val loss = 0.824, average loss = 0.775
# epoch 34: train loss = 0.739, val loss = 0.814, average loss = 0.777
# epoch 35: train loss = 0.739, val loss = 0.817, average loss = 0.778
# epoch 36: train loss = 0.721, val loss = 0.868, average loss = 0.794
# epoch 37: train loss = 0.716, val loss = 0.817, average loss = 0.766
# epoch 38: train loss = 0.721, val loss = 0.848, average loss = 0.785
# epoch 39: train loss = 0.733, val loss = 0.836, average loss = 0.784
# epoch 40: train loss = 0.719, val loss = 0.816, average loss = 0.768
# epoch 41: train loss = 0.713, val loss = 0.82, average loss = 0.766
# epoch 42: train loss = 0.71, val loss = 0.807, average loss = 0.759
# epoch 43: train loss = 0.71, val loss = 0.807, average loss = 0.759
# epoch 39: train loss = 0.718, val loss = 0.74, average loss = 0.729
# epoch 40: train loss = 0.718, val loss = 0.743, average loss = 0.731
# epoch 41: train loss = 0.719, val loss = 0.74, average loss = 0.73
# epoch 42: train loss = 0.718, val loss = 0.738, average loss = 0.728
# epoch 43: train loss = 0.718, val loss = 0.744, average loss = 0.731
# epoch 44: train loss = 0.716, val loss = 0.746, average loss = 0.731
# epoch 45: train loss = 0.716, val loss = 0.744, average loss = 0.73
# epoch 46: train loss = 0.716, val loss = 0.743, average loss = 0.729
# epoch 47: train loss = 0.716, val loss = 0.747, average loss = 0.731
# epoch 48: train loss = 0.715, val loss = 0.744, average loss = 0.73
# epoch 49: train loss = 0.715, val loss = 0.745, average loss = 0.73
# epoch 50: train loss = 0.715, val loss = 0.745, average loss = 0.73
# FOLD 5:
# epoch 1: train loss = 0.725, val loss = 0.704, average loss = 0.715
# epoch 2: train loss = 0.735, val loss = 0.712, average loss = 0.723
# epoch 3: train loss = 0.747, val loss = 0.75, average loss = 0.749
# epoch 4: train loss = 0.765, val loss = 0.717, average loss = 0.741
# epoch 5: train loss = 0.754, val loss = 0.77, average loss = 0.762
# epoch 6: train loss = 0.765, val loss = 0.712, average loss = 0.738
# epoch 7: train loss = 0.734, val loss = 0.736, average loss = 0.735
# epoch 8: train loss = 0.758, val loss = 0.725, average loss = 0.741
# epoch 9: train loss = 0.757, val loss = 0.753, average loss = 0.755
# epoch 10: train loss = 0.765, val loss = 0.715, average loss = 0.74
# epoch 11: train loss = 0.736, val loss = 0.711, average loss = 0.724
# epoch 12: train loss = 0.73, val loss = 0.713, average loss = 0.721
# epoch 13: train loss = 0.73, val loss = 0.743, average loss = 0.737
# epoch 14: train loss = 0.749, val loss = 0.716, average loss = 0.733
# epoch 15: train loss = 0.746, val loss = 0.769, average loss = 0.757
# epoch 16: train loss = 0.739, val loss = 0.739, average loss = 0.739
# epoch 17: train loss = 0.75, val loss = 0.734, average loss = 0.742
# epoch 18: train loss = 0.725, val loss = 0.731, average loss = 0.728
# epoch 19: train loss = 0.732, val loss = 0.755, average loss = 0.743
# epoch 20: train loss = 0.717, val loss = 0.738, average loss = 0.727
# epoch 21: train loss = 0.725, val loss = 0.74, average loss = 0.732
# epoch 22: train loss = 0.716, val loss = 0.712, average loss = 0.714
# epoch 23: train loss = 0.713, val loss = 0.715, average loss = 0.714
# epoch 24: train loss = 0.719, val loss = 0.714, average loss = 0.717
# epoch 25: train loss = 0.717, val loss = 0.742, average loss = 0.73
# epoch 26: train loss = 0.711, val loss = 0.716, average loss = 0.714
# epoch 27: train loss = 0.712, val loss = 0.722, average loss = 0.717
# epoch 28: train loss = 0.726, val loss = 0.738, average loss = 0.732
# epoch 29: train loss = 0.717, val loss = 0.733, average loss = 0.725
# epoch 30: train loss = 0.714, val loss = 0.708, average loss = 0.711
# epoch 31: train loss = 0.716, val loss = 0.733, average loss = 0.724
# epoch 32: train loss = 0.715, val loss = 0.718, average loss = 0.716
# epoch 33: train loss = 0.718, val loss = 0.784, average loss = 0.751
# epoch 34: train loss = 0.74, val loss = 0.734, average loss = 0.737
# epoch 35: train loss = 0.746, val loss = 0.746, average loss = 0.746
# epoch 36: train loss = 0.746, val loss = 0.904, average loss = 0.825
# epoch 37: train loss = 0.737, val loss = 0.735, average loss = 0.736
# epoch 38: train loss = 0.723, val loss = 0.754, average loss = 0.739
# epoch 39: train loss = 0.739, val loss = 0.752, average loss = 0.746
# epoch 40: train loss = 0.747, val loss = 0.788, average loss = 0.767
# epoch 41: train loss = 0.709, val loss = 0.773, average loss = 0.741
# epoch 42: train loss = 0.708, val loss = 0.769, average loss = 0.739
# epoch 43: train loss = 0.711, val loss = 0.754, average loss = 0.732
# epoch 44: train loss = 0.707, val loss = 0.777, average loss = 0.742
# epoch 45: train loss = 0.703, val loss = 0.77, average loss = 0.737
# epoch 46: train loss = 0.705, val loss = 0.774, average loss = 0.74
# epoch 47: train loss = 0.706, val loss = 0.761, average loss = 0.733
# epoch 48: train loss = 0.71, val loss = 0.784, average loss = 0.747
# epoch 49: train loss = 0.711, val loss = 0.79, average loss = 0.75
# epoch 50: train loss = 0.727, val loss = 0.784, average loss = 0.756
# The model for participant 2 has been saved
# Leaving participant 2 out
# (1) Confusion matrix:
#  [[2 0 0]
#  [3 2 0]
#  [0 0 0]]
# (2) micro F1 score = 0.57
# (3) Weighted F1 score = 0.57
# (4) Percentage Classification accuracy = 57.14%
# --------------------------------
# LEAVING PARTICIPANT 3 OUT:
# FOLD 1:
# epoch 1: train loss = 0.748, val loss = 0.746, average loss = 0.747
# epoch 2: train loss = 0.745, val loss = 0.749, average loss = 0.747
# epoch 3: train loss = 0.74, val loss = 0.733, average loss = 0.736
# epoch 4: train loss = 0.769, val loss = 0.766, average loss = 0.767
# epoch 5: train loss = 0.771, val loss = 0.787, average loss = 0.779
# epoch 6: train loss = 0.781, val loss = 0.772, average loss = 0.776
# epoch 7: train loss = 0.786, val loss = 0.802, average loss = 0.794
# epoch 8: train loss = 0.756, val loss = 0.769, average loss = 0.762
# epoch 9: train loss = 0.759, val loss = 0.828, average loss = 0.794
# epoch 10: train loss = 0.791, val loss = 0.796, average loss = 0.793
# epoch 11: train loss = 0.767, val loss = 0.817, average loss = 0.792
# epoch 12: train loss = 0.755, val loss = 0.782, average loss = 0.769
# epoch 13: train loss = 0.748, val loss = 0.914, average loss = 0.831
# epoch 14: train loss = 0.775, val loss = 0.818, average loss = 0.796
# epoch 15: train loss = 0.793, val loss = 0.823, average loss = 0.808
# epoch 16: train loss = 0.825, val loss = 0.816, average loss = 0.821
# epoch 17: train loss = 0.8, val loss = 0.803, average loss = 0.802
# epoch 18: train loss = 0.768, val loss = 0.761, average loss = 0.764
# epoch 19: train loss = 0.764, val loss = 0.83, average loss = 0.797
# epoch 20: train loss = 0.783, val loss = 0.868, average loss = 0.826
# epoch 21: train loss = 0.77, val loss = 0.825, average loss = 0.798
# epoch 22: train loss = 0.799, val loss = 0.817, average loss = 0.808
# epoch 23: train loss = 0.769, val loss = 0.795, average loss = 0.782
# epoch 24: train loss = 0.759, val loss = 0.794, average loss = 0.776
# epoch 25: train loss = 0.758, val loss = 0.86, average loss = 0.809
# epoch 26: train loss = 0.767, val loss = 0.813, average loss = 0.79
# epoch 27: train loss = 0.767, val loss = 0.865, average loss = 0.816
# epoch 28: train loss = 0.764, val loss = 0.795, average loss = 0.779
# epoch 29: train loss = 0.748, val loss = 0.811, average loss = 0.78
# epoch 30: train loss = 0.735, val loss = 0.875, average loss = 0.805
# epoch 31: train loss = 0.745, val loss = 0.808, average loss = 0.777
# epoch 32: train loss = 0.737, val loss = 0.781, average loss = 0.759
# epoch 33: train loss = 0.746, val loss = 0.809, average loss = 0.778
# epoch 34: train loss = 0.725, val loss = 0.829, average loss = 0.777
# epoch 35: train loss = 0.728, val loss = 0.79, average loss = 0.759
# epoch 36: train loss = 0.73, val loss = 0.802, average loss = 0.766
# epoch 37: train loss = 0.727, val loss = 0.819, average loss = 0.773
# epoch 38: train loss = 0.724, val loss = 0.817, average loss = 0.77
# epoch 39: train loss = 0.722, val loss = 0.827, average loss = 0.775
# epoch 40: train loss = 0.725, val loss = 0.824, average loss = 0.774
# epoch 41: train loss = 0.713, val loss = 0.804, average loss = 0.759
# epoch 42: train loss = 0.711, val loss = 0.807, average loss = 0.759
# epoch 43: train loss = 0.715, val loss = 0.81, average loss = 0.762
# epoch 44: train loss = 0.724, val loss = 0.871, average loss = 0.798
# epoch 45: train loss = 0.719, val loss = 0.869, average loss = 0.794
# epoch 46: train loss = 0.784, val loss = 0.864, average loss = 0.824
# epoch 47: train loss = 0.748, val loss = 0.83, average loss = 0.789
# epoch 48: train loss = 0.726, val loss = 0.859, average loss = 0.793
# epoch 49: train loss = 0.753, val loss = 0.815, average loss = 0.784
# epoch 50: train loss = 0.757, val loss = 0.875, average loss = 0.816
# FOLD 2:
# epoch 1: train loss = 0.804, val loss = 0.789, average loss = 0.797
# epoch 2: train loss = 0.799, val loss = 0.87, average loss = 0.835
# epoch 3: train loss = 0.79, val loss = 0.799, average loss = 0.795
# epoch 4: train loss = 0.774, val loss = 0.861, average loss = 0.817
# epoch 5: train loss = 0.813, val loss = 0.862, average loss = 0.838
# epoch 6: train loss = 0.836, val loss = 0.873, average loss = 0.854
# epoch 7: train loss = 0.784, val loss = 0.767, average loss = 0.775
# epoch 8: train loss = 0.79, val loss = 0.81, average loss = 0.8
# epoch 9: train loss = 0.793, val loss = 0.8, average loss = 0.796
# epoch 10: train loss = 0.791, val loss = 0.793, average loss = 0.792
# epoch 11: train loss = 0.781, val loss = 0.853, average loss = 0.817
# epoch 12: train loss = 0.812, val loss = 0.783, average loss = 0.798
# epoch 13: train loss = 0.763, val loss = 0.785, average loss = 0.774
# epoch 14: train loss = 0.768, val loss = 0.912, average loss = 0.84
# epoch 15: train loss = 0.762, val loss = 0.87, average loss = 0.816
# epoch 16: train loss = 0.772, val loss = 0.866, average loss = 0.819
# epoch 17: train loss = 0.77, val loss = 0.831, average loss = 0.8
# epoch 18: train loss = 0.744, val loss = 0.845, average loss = 0.794
# epoch 19: train loss = 0.781, val loss = 0.876, average loss = 0.828
# epoch 20: train loss = 0.783, val loss = 0.792, average loss = 0.788
# epoch 21: train loss = 0.745, val loss = 0.807, average loss = 0.776
# epoch 22: train loss = 0.734, val loss = 0.804, average loss = 0.769
# epoch 23: train loss = 0.73, val loss = 0.769, average loss = 0.749
# epoch 24: train loss = 0.732, val loss = 0.759, average loss = 0.745
# epoch 25: train loss = 0.774, val loss = 0.783, average loss = 0.779
# epoch 26: train loss = 0.767, val loss = 0.775, average loss = 0.771
# epoch 27: train loss = 0.762, val loss = 0.824, average loss = 0.793
# epoch 28: train loss = 0.73, val loss = 0.801, average loss = 0.765
# epoch 29: train loss = 0.721, val loss = 0.753, average loss = 0.737
# epoch 30: train loss = 0.721, val loss = 0.765, average loss = 0.743
# epoch 31: train loss = 0.742, val loss = 0.771, average loss = 0.756
# epoch 32: train loss = 0.727, val loss = 0.813, average loss = 0.77
# epoch 33: train loss = 0.716, val loss = 0.779, average loss = 0.748
# epoch 34: train loss = 0.711, val loss = 0.776, average loss = 0.743
# epoch 35: train loss = 0.711, val loss = 0.772, average loss = 0.741
# epoch 36: train loss = 0.71, val loss = 0.771, average loss = 0.741
# epoch 37: train loss = 0.71, val loss = 0.774, average loss = 0.742
# epoch 38: train loss = 0.71, val loss = 0.767, average loss = 0.739
# epoch 39: train loss = 0.71, val loss = 0.775, average loss = 0.742
# epoch 40: train loss = 0.71, val loss = 0.771, average loss = 0.741
# epoch 41: train loss = 0.71, val loss = 0.772, average loss = 0.741
# epoch 42: train loss = 0.71, val loss = 0.78, average loss = 0.745
# epoch 43: train loss = 0.71, val loss = 0.778, average loss = 0.744
# epoch 44: train loss = 0.71, val loss = 0.77, average loss = 0.74
# epoch 45: train loss = 0.71, val loss = 0.767, average loss = 0.739
# epoch 46: train loss = 0.71, val loss = 0.776, average loss = 0.743
# epoch 47: train loss = 0.714, val loss = 0.778, average loss = 0.746
# epoch 48: train loss = 0.719, val loss = 0.825, average loss = 0.772
# epoch 49: train loss = 0.713, val loss = 0.779, average loss = 0.746
# epoch 50: train loss = 0.711, val loss = 0.771, average loss = 0.741
# FOLD 3:
# epoch 1: train loss = 0.728, val loss = 0.707, average loss = 0.717
# epoch 2: train loss = 0.744, val loss = 0.757, average loss = 0.75
# epoch 3: train loss = 0.76, val loss = 0.776, average loss = 0.768
# epoch 4: train loss = 0.747, val loss = 0.723, average loss = 0.735
# epoch 5: train loss = 0.723, val loss = 0.744, average loss = 0.734
# epoch 6: train loss = 0.745, val loss = 0.755, average loss = 0.75
# epoch 7: train loss = 0.763, val loss = 0.755, average loss = 0.759
# epoch 8: train loss = 0.75, val loss = 0.729, average loss = 0.739
# epoch 9: train loss = 0.719, val loss = 0.729, average loss = 0.724
# epoch 10: train loss = 0.732, val loss = 0.777, average loss = 0.754
# epoch 11: train loss = 0.734, val loss = 0.807, average loss = 0.77
# epoch 12: train loss = 0.757, val loss = 0.781, average loss = 0.769
# epoch 13: train loss = 0.746, val loss = 0.74, average loss = 0.743
# epoch 14: train loss = 0.757, val loss = 0.865, average loss = 0.811
# epoch 15: train loss = 0.746, val loss = 0.77, average loss = 0.758
# epoch 16: train loss = 0.738, val loss = 0.774, average loss = 0.756
# epoch 17: train loss = 0.742, val loss = 0.803, average loss = 0.772
# epoch 18: train loss = 0.752, val loss = 0.829, average loss = 0.79
# epoch 19: train loss = 0.739, val loss = 0.784, average loss = 0.761
# epoch 20: train loss = 0.734, val loss = 0.778, average loss = 0.756
# epoch 21: train loss = 0.725, val loss = 0.803, average loss = 0.764
# epoch 22: train loss = 0.725, val loss = 0.738, average loss = 0.731
# epoch 23: train loss = 0.722, val loss = 0.753, average loss = 0.738
# epoch 24: train loss = 0.718, val loss = 0.751, average loss = 0.734
# epoch 25: train loss = 0.716, val loss = 0.767, average loss = 0.742
# epoch 26: train loss = 0.714, val loss = 0.748, average loss = 0.731
# epoch 27: train loss = 0.717, val loss = 0.77, average loss = 0.744
# epoch 28: train loss = 0.743, val loss = 0.767, average loss = 0.755
# epoch 29: train loss = 0.734, val loss = 0.788, average loss = 0.761
# epoch 30: train loss = 0.731, val loss = 0.836, average loss = 0.783
# epoch 31: train loss = 0.728, val loss = 0.788, average loss = 0.758
# epoch 32: train loss = 0.723, val loss = 0.78, average loss = 0.751
# epoch 33: train loss = 0.721, val loss = 0.782, average loss = 0.752
# epoch 34: train loss = 0.716, val loss = 0.782, average loss = 0.749
# epoch 35: train loss = 0.712, val loss = 0.789, average loss = 0.751
# epoch 36: train loss = 0.723, val loss = 0.791, average loss = 0.757
# epoch 37: train loss = 0.716, val loss = 0.777, average loss = 0.747
# epoch 38: train loss = 0.738, val loss = 0.778, average loss = 0.758
# epoch 39: train loss = 0.731, val loss = 0.784, average loss = 0.758
# epoch 40: train loss = 0.725, val loss = 0.795, average loss = 0.76
# epoch 41: train loss = 0.71, val loss = 0.783, average loss = 0.746
# epoch 42: train loss = 0.719, val loss = 0.786, average loss = 0.753
# epoch 43: train loss = 0.716, val loss = 0.761, average loss = 0.739
# epoch 44: train loss = 0.715, val loss = 0.771, average loss = 0.743
# epoch 45: train loss = 0.711, val loss = 0.815, average loss = 0.763
# epoch 46: train loss = 0.73, val loss = 0.771, average loss = 0.751
# epoch 47: train loss = 0.721, val loss = 0.786, average loss = 0.753
# epoch 48: train loss = 0.72, val loss = 0.8, average loss = 0.76
# epoch 49: train loss = 0.712, val loss = 0.819, average loss = 0.765
# epoch 50: train loss = 0.718, val loss = 0.848, average loss = 0.783
# FOLD 4:
# epoch 1: train loss = 0.766, val loss = 0.704, average loss = 0.735
# epoch 2: train loss = 0.74, val loss = 0.72, average loss = 0.73
# epoch 3: train loss = 0.735, val loss = 0.718, average loss = 0.727
# epoch 4: train loss = 0.748, val loss = 0.704, average loss = 0.726
# epoch 5: train loss = 0.737, val loss = 0.732, average loss = 0.734
# epoch 6: train loss = 0.737, val loss = 0.727, average loss = 0.732
# epoch 7: train loss = 0.721, val loss = 0.724, average loss = 0.722
# epoch 8: train loss = 0.732, val loss = 0.703, average loss = 0.717
# epoch 9: train loss = 0.728, val loss = 0.745, average loss = 0.737
# epoch 10: train loss = 0.72, val loss = 0.726, average loss = 0.723
# epoch 11: train loss = 0.717, val loss = 0.72, average loss = 0.719
# epoch 12: train loss = 0.713, val loss = 0.714, average loss = 0.714
# epoch 13: train loss = 0.713, val loss = 0.734, average loss = 0.723
# epoch 14: train loss = 0.716, val loss = 0.72, average loss = 0.718
# epoch 15: train loss = 0.738, val loss = 0.719, average loss = 0.729
# epoch 16: train loss = 0.738, val loss = 0.714, average loss = 0.726
# epoch 17: train loss = 0.738, val loss = 0.781, average loss = 0.76
# epoch 18: train loss = 0.745, val loss = 0.726, average loss = 0.736
# epoch 19: train loss = 0.749, val loss = 0.747, average loss = 0.748
# epoch 20: train loss = 0.743, val loss = 0.766, average loss = 0.754
# epoch 21: train loss = 0.72, val loss = 0.708, average loss = 0.714
# epoch 22: train loss = 0.709, val loss = 0.716, average loss = 0.713
# epoch 23: train loss = 0.712, val loss = 0.707, average loss = 0.709
# epoch 24: train loss = 0.728, val loss = 0.702, average loss = 0.715
# epoch 25: train loss = 0.713, val loss = 0.735, average loss = 0.724
# epoch 26: train loss = 0.724, val loss = 0.703, average loss = 0.714
# epoch 27: train loss = 0.714, val loss = 0.697, average loss = 0.705
# epoch 28: train loss = 0.703, val loss = 0.733, average loss = 0.718
# epoch 29: train loss = 0.739, val loss = 0.752, average loss = 0.746
# epoch 30: train loss = 0.709, val loss = 0.716, average loss = 0.713
# epoch 31: train loss = 0.725, val loss = 0.713, average loss = 0.719
# epoch 32: train loss = 0.716, val loss = 0.725, average loss = 0.721
# epoch 33: train loss = 0.72, val loss = 0.764, average loss = 0.742
# epoch 34: train loss = 0.787, val loss = 0.736, average loss = 0.761
# epoch 35: train loss = 0.806, val loss = 0.777, average loss = 0.791
# epoch 36: train loss = 0.773, val loss = 0.741, average loss = 0.757
# epoch 37: train loss = 0.761, val loss = 0.777, average loss = 0.769
# epoch 38: train loss = 0.761, val loss = 0.746, average loss = 0.753
# epoch 39: train loss = 0.745, val loss = 0.738, average loss = 0.742
# epoch 40: train loss = 0.754, val loss = 0.807, average loss = 0.781
# ...
# epoch 26: train loss = 0.682, val loss = 0.65, average loss = 0.666
# epoch 27: train loss = 0.699, val loss = 0.662, average loss = 0.681
# epoch 28: train loss = 0.689, val loss = 0.655, average loss = 0.672
# epoch 29: train loss = 0.689, val loss = 0.68, average loss = 0.684
# epoch 30: train loss = 0.685, val loss = 0.688, average loss = 0.687
# epoch 31: train loss = 0.683, val loss = 0.672, average loss = 0.678
# epoch 32: train loss = 0.693, val loss = 0.731, average loss = 0.712
# epoch 33: train loss = 0.695, val loss = 0.699, average loss = 0.697
# epoch 34: train loss = 0.676, val loss = 0.713, average loss = 0.694
# epoch 35: train loss = 0.682, val loss = 0.706, average loss = 0.694
# epoch 36: train loss = 0.679, val loss = 0.671, average loss = 0.675
# epoch 37: train loss = 0.672, val loss = 0.706, average loss = 0.689
# epoch 38: train loss = 0.7, val loss = 0.68, average loss = 0.69
# epoch 39: train loss = 0.676, val loss = 0.668, average loss = 0.672
# epoch 40: train loss = 0.676, val loss = 0.663, average loss = 0.669
# epoch 41: train loss = 0.673, val loss = 0.661, average loss = 0.667
# epoch 42: train loss = 0.666, val loss = 0.664, average loss = 0.665
# epoch 43: train loss = 0.665, val loss = 0.659, average loss = 0.662
# epoch 44: train loss = 0.667, val loss = 0.679, average loss = 0.673
# epoch 45: train loss = 0.672, val loss = 0.653, average loss = 0.663
# epoch 46: train loss = 0.665, val loss = 0.65, average loss = 0.658
# epoch 47: train loss = 0.673, val loss = 0.651, average loss = 0.662
# epoch 48: train loss = 0.672, val loss = 0.65, average loss = 0.661
# epoch 49: train loss = 0.669, val loss = 0.645, average loss = 0.657
# epoch 50: train loss = 0.673, val loss = 0.668, average loss = 0.671
# FOLD 2:
# epoch 1: train loss = 0.665, val loss = 0.663, average loss = 0.664
# epoch 2: train loss = 0.682, val loss = 0.653, average loss = 0.667
# epoch 3: train loss = 0.672, val loss = 0.659, average loss = 0.665
# epoch 4: train loss = 0.674, val loss = 0.683, average loss = 0.679
# epoch 5: train loss = 0.69, val loss = 0.652, average loss = 0.671
# epoch 6: train loss = 0.667, val loss = 0.653, average loss = 0.66
# epoch 7: train loss = 0.665, val loss = 0.671, average loss = 0.668
# epoch 8: train loss = 0.681, val loss = 0.656, average loss = 0.669
# epoch 9: train loss = 0.676, val loss = 0.666, average loss = 0.671
# epoch 10: train loss = 0.677, val loss = 0.666, average loss = 0.672
# epoch 11: train loss = 0.67, val loss = 0.699, average loss = 0.685
# epoch 12: train loss = 0.671, val loss = 0.669, average loss = 0.67
# epoch 13: train loss = 0.661, val loss = 0.675, average loss = 0.668
# epoch 14: train loss = 0.666, val loss = 0.667, average loss = 0.666
# epoch 15: train loss = 0.665, val loss = 0.661, average loss = 0.663
# epoch 16: train loss = 0.656, val loss = 0.672, average loss = 0.664
# epoch 17: train loss = 0.663, val loss = 0.665, average loss = 0.664
# epoch 18: train loss = 0.663, val loss = 0.652, average loss = 0.658
# epoch 19: train loss = 0.662, val loss = 0.652, average loss = 0.657
# epoch 20: train loss = 0.66, val loss = 0.652, average loss = 0.656
# epoch 21: train loss = 0.658, val loss = 0.652, average loss = 0.655
# epoch 22: train loss = 0.662, val loss = 0.654, average loss = 0.658
# epoch 23: train loss = 0.658, val loss = 0.652, average loss = 0.655
# epoch 24: train loss = 0.657, val loss = 0.663, average loss = 0.66
# epoch 25: train loss = 0.658, val loss = 0.653, average loss = 0.655
# epoch 26: train loss = 0.658, val loss = 0.653, average loss = 0.655
# epoch 27: train loss = 0.655, val loss = 0.652, average loss = 0.653
# epoch 28: train loss = 0.663, val loss = 0.657, average loss = 0.66
# epoch 29: train loss = 0.662, val loss = 0.659, average loss = 0.66
# epoch 30: train loss = 0.659, val loss = 0.666, average loss = 0.662
# epoch 31: train loss = 0.657, val loss = 0.653, average loss = 0.655
# epoch 32: train loss = 0.661, val loss = 0.653, average loss = 0.657
# epoch 33: train loss = 0.661, val loss = 0.653, average loss = 0.657
# epoch 34: train loss = 0.662, val loss = 0.657, average loss = 0.66
# epoch 35: train loss = 0.661, val loss = 0.656, average loss = 0.658
# epoch 36: train loss = 0.661, val loss = 0.655, average loss = 0.658
# epoch 37: train loss = 0.661, val loss = 0.655, average loss = 0.658
# epoch 38: train loss = 0.661, val loss = 0.655, average loss = 0.658
# epoch 39: train loss = 0.661, val loss = 0.654, average loss = 0.657
# epoch 40: train loss = 0.661, val loss = 0.66, average loss = 0.66
# epoch 41: train loss = 0.661, val loss = 0.656, average loss = 0.658
# epoch 42: train loss = 0.66, val loss = 0.655, average loss = 0.658
# epoch 43: train loss = 0.66, val loss = 0.656, average loss = 0.658
# epoch 44: train loss = 0.659, val loss = 0.672, average loss = 0.666
# epoch 45: train loss = 0.663, val loss = 0.654, average loss = 0.659
# epoch 46: train loss = 0.661, val loss = 0.653, average loss = 0.657
# epoch 47: train loss = 0.662, val loss = 0.663, average loss = 0.663
# epoch 48: train loss = 0.665, val loss = 0.654, average loss = 0.659
# epoch 49: train loss = 0.66, val loss = 0.654, average loss = 0.657
# epoch 50: train loss = 0.66, val loss = 0.659, average loss = 0.659
# FOLD 3:
# epoch 1: train loss = 0.658, val loss = 0.646, average loss = 0.652
# epoch 2: train loss = 0.657, val loss = 0.646, average loss = 0.652
# epoch 3: train loss = 0.658, val loss = 0.649, average loss = 0.653
# epoch 4: train loss = 0.657, val loss = 0.647, average loss = 0.652
# epoch 5: train loss = 0.657, val loss = 0.647, average loss = 0.652
# epoch 6: train loss = 0.657, val loss = 0.646, average loss = 0.651
# epoch 7: train loss = 0.657, val loss = 0.646, average loss = 0.651
# epoch 8: train loss = 0.657, val loss = 0.646, average loss = 0.651
# epoch 9: train loss = 0.657, val loss = 0.645, average loss = 0.651
# epoch 10: train loss = 0.656, val loss = 0.645, average loss = 0.651
# epoch 11: train loss = 0.657, val loss = 0.645, average loss = 0.651
# epoch 12: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 13: train loss = 0.656, val loss = 0.645, average loss = 0.651
# epoch 14: train loss = 0.657, val loss = 0.648, average loss = 0.652
# epoch 15: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 16: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 17: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 18: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 19: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 20: train loss = 0.657, val loss = 0.646, average loss = 0.651
# epoch 21: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 22: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 23: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 24: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 25: train loss = 0.656, val loss = 0.649, average loss = 0.653
# epoch 26: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 27: train loss = 0.656, val loss = 0.65, average loss = 0.653
# epoch 28: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 29: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 30: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 31: train loss = 0.657, val loss = 0.647, average loss = 0.652
# epoch 32: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 33: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 34: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 35: train loss = 0.656, val loss = 0.649, average loss = 0.652
# epoch 36: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 37: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 38: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 39: train loss = 0.656, val loss = 0.647, average loss = 0.651
# epoch 40: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 41: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 42: train loss = 0.657, val loss = 0.649, average loss = 0.653
# epoch 43: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 44: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 45: train loss = 0.656, val loss = 0.648, average loss = 0.652
# epoch 46: train loss = 0.656, val loss = 0.646, average loss = 0.651
# epoch 47: train loss = 0.657, val loss = 0.65, average loss = 0.654
# epoch 48: train loss = 0.657, val loss = 0.648, average loss = 0.652
# epoch 49: train loss = 0.656, val loss = 0.647, average loss = 0.652
# epoch 50: train loss = 0.656, val loss = 0.647, average loss = 0.652
# FOLD 4:
# epoch 1: train loss = 0.66, val loss = 0.638, average loss = 0.649
# epoch 2: train loss = 0.659, val loss = 0.639, average loss = 0.649
# epoch 3: train loss = 0.66, val loss = 0.645, average loss = 0.653
# epoch 4: train loss = 0.661, val loss = 0.644, average loss = 0.652
# epoch 5: train loss = 0.692, val loss = 0.641, average loss = 0.666
# epoch 6: train loss = 0.677, val loss = 0.642, average loss = 0.659
# epoch 7: train loss = 0.676, val loss = 0.66, average loss = 0.668
# epoch 8: train loss = 0.676, val loss = 0.649, average loss = 0.663
# epoch 9: train loss = 0.665, val loss = 0.642, average loss = 0.653
# epoch 10: train loss = 0.67, val loss = 0.657, average loss = 0.664
# epoch 11: train loss = 0.67, val loss = 0.641, average loss = 0.655
# epoch 12: train loss = 0.666, val loss = 0.64, average loss = 0.653
# epoch 13: train loss = 0.663, val loss = 0.664, average loss = 0.663
# epoch 14: train loss = 0.664, val loss = 0.641, average loss = 0.652
# epoch 15: train loss = 0.658, val loss = 0.645, average loss = 0.651
# epoch 16: train loss = 0.664, val loss = 0.671, average loss = 0.668
# epoch 17: train loss = 0.659, val loss = 0.64, average loss = 0.649
# epoch 18: train loss = 0.664, val loss = 0.644, average loss = 0.654
# epoch 19: train loss = 0.661, val loss = 0.641, average loss = 0.651
# epoch 20: train loss = 0.66, val loss = 0.641, average loss = 0.65
# epoch 21: train loss = 0.662, val loss = 0.641, average loss = 0.652
# epoch 22: train loss = 0.661, val loss = 0.656, average loss = 0.659
# epoch 23: train loss = 0.661, val loss = 0.646, average loss = 0.653
# epoch 24: train loss = 0.659, val loss = 0.673, average loss = 0.666
# epoch 25: train loss = 0.665, val loss = 0.679, average loss = 0.672
# epoch 26: train loss = 0.662, val loss = 0.653, average loss = 0.657
# epoch 27: train loss = 0.661, val loss = 0.644, average loss = 0.652
# epoch 28: train loss = 0.661, val loss = 0.653, average loss = 0.657
# epoch 29: train loss = 0.661, val loss = 0.646, average loss = 0.653
# epoch 30: train loss = 0.661, val loss = 0.648, average loss = 0.655
# epoch 31: train loss = 0.663, val loss = 0.667, average loss = 0.665
# epoch 32: train loss = 0.663, val loss = 0.65, average loss = 0.657
# epoch 33: train loss = 0.658, val loss = 0.652, average loss = 0.655
# epoch 34: train loss = 0.662, val loss = 0.651, average loss = 0.657
# epoch 35: train loss = 0.66, val loss = 0.649, average loss = 0.655
# epoch 36: train loss = 0.657, val loss = 0.659, average loss = 0.658
# epoch 37: train loss = 0.659, val loss = 0.66, average loss = 0.66
# epoch 38: train loss = 0.663, val loss = 0.644, average loss = 0.654
# epoch 39: train loss = 0.656, val loss = 0.676, average loss = 0.666
# epoch 40: train loss = 0.66, val loss = 0.657, average loss = 0.658
# epoch 41: train loss = 0.661, val loss = 0.686, average loss = 0.674
# epoch 42: train loss = 0.666, val loss = 0.655, average loss = 0.661
# epoch 43: train loss = 0.657, val loss = 0.656, average loss = 0.656
# epoch 44: train loss = 0.657, val loss = 0.654, average loss = 0.656
# epoch 45: train loss = 0.661, val loss = 0.653, average loss = 0.657
# epoch 46: train loss = 0.657, val loss = 0.684, average loss = 0.671
# epoch 47: train loss = 0.659, val loss = 0.653, average loss = 0.656
# epoch 48: train loss = 0.657, val loss = 0.655, average loss = 0.656
# epoch 49: train loss = 0.657, val loss = 0.651, average loss = 0.654
# epoch 50: train loss = 0.657, val loss = 0.654, average loss = 0.655
# FOLD 5:
# epoch 1: train loss = 0.642, val loss = 0.712, average loss = 0.677
# epoch 2: train loss = 0.639, val loss = 0.713, average loss = 0.676
# epoch 3: train loss = 0.639, val loss = 0.713, average loss = 0.676
# epoch 4: train loss = 0.639, val loss = 0.713, average loss = 0.676
# epoch 5: train loss = 0.642, val loss = 0.713, average loss = 0.677
# epoch 6: train loss = 0.639, val loss = 0.709, average loss = 0.674
# epoch 7: train loss = 0.642, val loss = 0.713, average loss = 0.677
# epoch 8: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 9: train loss = 0.638, val loss = 0.713, average loss = 0.676
# epoch 10: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 11: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 12: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 13: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 14: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 15: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 16: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 17: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 18: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 19: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 20: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 21: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 22: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 23: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 24: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 25: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 26: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 27: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 28: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 29: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 30: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 31: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 32: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 33: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 34: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 35: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 36: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 37: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 38: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 39: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 40: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 41: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 42: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 43: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 44: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 45: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 46: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 47: train loss = 0.638, val loss = 0.713, average loss = 0.675
# epoch 48: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 49: train loss = 0.638, val loss = 0.712, average loss = 0.675
# epoch 50: train loss = 0.638, val loss = 0.713, average loss = 0.675
# The model for participant 25 has been saved
# Leaving participant 25 out
# (1) Confusion matrix:
#  [[0 0 0]
#  [0 4 0]
#  [0 0 3]]
# (2) micro F1 score = 1.0
# (3) Weighted F1 score = 1.0
# (4) Percentage Classification accuracy = 100.0%
# --------------------------------
# Using Leave One Participant Out CV (LOPOCV):
# (1) Confusion matrix:
#  [[ 20  18   4]
#  [ 10 108   2]
#  [  4   8  22]]
# (2) Average micro F1 score = 0.77
# (3) Average weighted F1 score = 0.72
# (4) Average Percentage Classification accuracy = 76.53%

# %% [markdown]
# ## Model 4 - LSTM + fully connected layers using only the emg data (48 features)

# %% [markdown]
# complete_emg = normalised_df.iloc[:,:59]
# hand0_emg = normalised_df.iloc[:,35:59]
# hand0_emg.head()

# %% [markdown]
# #hand0_emg = normalised_df.iloc[:,19:27]
# hand1_emg = normalised_df.iloc[:,35:59]
#
# emg_0 = normalised_df.iloc[:,:35]
# emg_1 = pd.concat([df_info, hand1_emg], axis=1)

# %% [markdown]
# ### Create the model

# %%
class LSTM_emg_features_properties(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.LSTM(24, 15, 1, batch_first=True)
        self.fc1 = nn.Linear(3 * 15 * 2, 25)
        self.fc2 = nn.Linear(25, 10)
        self.fc3 = nn.Linear(10, 5)
          
    def forward(self, x1, x2): #, x2
        x1, (hn, cn) = self.rnn(x1) #, (self.h0, self.c0)
        x1 = F.tanh(x1)
        x2, (hm, cm) = self.rnn(x2) # (self.h0, self.c0)
        x2 = F.tanh(x2)
        
        x = torch.cat((x1, x2), 2)
        
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return x
    
class LSTM_emg_features_ratings(nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = nn.LSTM(24+5, 15, 1, batch_first=True)
        self.fc1 = nn.Linear(3 * 15 * 2, 25)
        self.fc2 = nn.Linear(25, 10)
        self.fc3 = nn.Linear(10, 3)
          
    def forward(self, x1, x2): #, x2
        x1, (hn, cn) = self.rnn(x1) #, (self.h0, self.c0)
        x1 = F.tanh(x1)
        x2, (hm, cm) = self.rnn(x2) # (self.h0, self.c0)
        x2 = F.tanh(x2)
        
        x = torch.cat((x1, x2), 2)
        
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return x

# %% [markdown]
# ### Run the model

# %%
#LSTM_LOP0CV(emg_0, emg_1, model=LSTM_emg_features_properties(), num_folds=5, predicting_feature='property_id', learning_rate=0.005, num_epochs=70, random_state=num) #, num_inner_folds=5

# %% [markdown]
# ### Run the model for ratings

# %%
LSTM_LOP0CV(emg_0, emg_1, model=LSTM_emg_features_ratings(), num_folds=5, predicting_feature='rating_level_num', learning_rate=0.005, num_epochs=50, random_state=num) #, num_inner_folds=5
# Out:
# LEAVING PARTICIPANT 1 OUT:
# FOLD 1:
# epoch 1: train loss = 1.089, val loss = 1.046, average loss = 1.067
# epoch 2: train loss = 1.057, val loss = 1.007, average loss = 1.032
# epoch 3: train loss = 1.047, val loss = 0.992, average loss = 1.02
# epoch 4: train loss = 1.045, val loss = 0.989, average loss = 1.017
# epoch 5: train loss = 1.045, val loss = 0.989, average loss = 1.017
# epoch 6: train loss = 1.044, val loss = 0.987, average loss = 1.016
# epoch 7: train loss = 1.044, val loss = 0.986, average loss = 1.015
# epoch 8: train loss = 1.044, val loss = 0.985, average loss = 1.015
# epoch 9: train loss = 1.044, val loss = 0.985, average loss = 1.014
# epoch 10: train loss = 1.043, val loss = 0.983, average loss = 1.013
# epoch 11: train loss = 1.043, val loss = 0.984, average loss = 1.014
# epoch 12: train loss = 1.043, val loss = 0.984, average loss = 1.014
# epoch 13: train loss = 1.043, val loss = 0.982, average loss = 1.012
# epoch 14: train loss = 1.042, val loss = 0.982, average loss = 1.012
# epoch 15: train loss = 1.042, val loss = 0.983, average loss = 1.012
# epoch 16: train loss = 1.04, val loss = 0.984, average loss = 1.012
# epoch 17: train loss = 1.04, val loss = 0.981, average loss = 1.011
# epoch 18: train loss = 1.037, val loss = 0.978, average loss = 1.007
# epoch 19: train loss = 1.036, val loss = 0.976, average loss = 1.006
# epoch 20: train loss = 1.035, val loss = 0.976, average loss = 1.006
# epoch 21: train loss = 1.029, val loss = 0.978, average loss = 1.004
# epoch 22: train loss = 1.024, val loss = 0.994, average loss = 1.009
# epoch 23: train loss = 1.021, val loss = 0.972, average loss = 0.996
# epoch 24: train loss = 1.019, val loss = 0.971, average loss = 0.995
# epoch 25: train loss = 1.015, val loss = 0.975, average loss = 0.995
# epoch 26: train loss = 1.007, val loss = 0.981, average loss = 0.994
# epoch 27: train loss = 1.005, val loss = 0.975, average loss = 0.99
# epoch 28: train loss = 0.999, val loss = 0.968, average loss = 0.984
# epoch 29: train loss = 0.999, val loss = 0.968, average loss = 0.983
# epoch 30: train loss = 1.003, val loss = 0.964, average loss = 0.984
# epoch 31: train loss = 0.997, val loss = 0.975, average loss = 0.986
# epoch 32: train loss = 1.0, val loss = 0.962, average loss = 0.981
# epoch 33: train loss = 0.993, val loss = 0.967, average loss = 0.98
# epoch 34: train loss = 0.987, val loss = 0.975, average loss = 0.981
# epoch 35: train loss = 0.997, val loss = 0.963, average loss = 0.98
# epoch 36: train loss = 0.984, val loss = 0.966, average loss = 0.975
# epoch 37: train loss = 0.982, val loss = 0.967, average loss = 0.974
# epoch 38: train loss = 0.979, val loss = 0.963, average loss = 0.971
# epoch 39: train loss = 0.982, val loss = 0.964, average loss = 0.973
# epoch 40: train loss = 0.976, val loss = 0.963, average loss = 0.969
# epoch 41: train loss = 0.971, val loss = 0.965, average loss = 0.968
# epoch 42: train loss = 0.968, val loss = 0.963, average loss = 0.965
# epoch 43: train loss = 0.968, val loss = 0.964, average loss = 0.966
# epoch 44: train loss = 0.97, val loss = 0.963, average loss = 0.966
# epoch 45: train loss = 0.972, val loss = 0.965, average loss = 0.968
# epoch 46: train loss = 0.964, val loss = 0.961, average loss = 0.963
# epoch 47: train loss = 0.96, val loss = 0.962, average loss = 0.961
# epoch 48: train loss = 0.966, val loss = 0.963, average loss = 0.965
# epoch 49: train loss = 0.965, val loss = 0.961, average loss = 0.963
# epoch 50: train loss = 0.963, val loss = 0.96, average loss = 0.962
# FOLD 2:
# epoch 1: train loss = 0.955, val loss = 1.022, average loss = 0.989
# epoch 2: train loss = 0.946, val loss = 1.011, average loss = 0.978
# epoch 3: train loss = 0.944, val loss = 1.032, average loss = 0.988
# epoch 4: train loss = 0.939, val loss = 1.061, average loss = 1.0
# epoch 5: train loss = 0.95, val loss = 1.027, average loss = 0.988
# epoch 6: train loss = 0.936, val loss = 1.041, average loss = 0.988
# epoch 7: train loss = 0.926, val loss = 1.205, average loss = 1.066
# epoch 8: train loss = 0.944, val loss = 1.051, average loss = 0.997
# epoch 9: train loss = 0.941, val loss = 1.061, average loss = 1.001
# epoch 10: train loss = 0.94, val loss = 1.064, average loss = 1.002
# epoch 11: train loss = 0.92, val loss = 1.071, average loss = 0.996
# epoch 12: train loss = 0.937, val loss = 1.059, average loss = 0.998
# epoch 13: train loss = 0.928, val loss = 1.098, average loss = 1.013
# epoch 14: train loss = 0.92, val loss = 1.043, average loss = 0.982
# epoch 15: train loss = 0.936, val loss = 1.064, average loss = 1.0
# epoch 16: train loss = 0.926, val loss = 1.042, average loss = 0.984
# epoch 17: train loss = 0.913, val loss = 1.068, average loss = 0.99
# epoch 18: train loss = 0.914, val loss = 1.081, average loss = 0.998
# epoch 19: train loss = 0.924, val loss = 1.057, average loss = 0.99
# epoch 20: train loss = 0.935, val loss = 1.125, average loss = 1.03
# epoch 21: train loss = 0.912, val loss = 1.05, average loss = 0.981
# epoch 22: train loss = 0.916, val loss = 1.093, average loss = 1.004
# epoch 23: train loss = 0.912, val loss = 1.09, average loss = 1.001
# epoch 24: train loss = 0.909, val loss = 1.083, average loss = 0.996
# epoch 25: train loss = 0.905, val loss = 1.083, average loss = 0.994
# epoch 26: train loss = 0.911, val loss = 1.086, average loss = 0.998
# epoch 27: train loss = 0.902, val loss = 1.048, average loss = 0.975
# epoch 28: train loss = 0.909, val loss = 1.081, average loss = 0.995
# epoch 29: train loss = 0.925, val loss = 1.107, average loss = 1.016
# epoch 30: train loss = 0.905, val loss = 1.071, average loss = 0.988
# epoch 31: train loss = 0.895, val loss = 1.11, average loss = 1.003
# epoch 32: train loss = 0.901, val loss = 1.054, average loss = 0.978
# epoch 33: train loss = 0.93, val loss = 1.107, average loss = 1.019
# epoch 34: train loss = 0.97, val loss = 1.071, average loss = 1.021
# epoch 35: train loss = 0.956, val loss = 1.038, average loss = 0.997
# epoch 36: train loss = 0.94, val loss = 1.032, average loss = 0.986
# epoch 37: train loss = 0.935, val loss = 1.056, average loss = 0.996
# epoch 38: train loss = 0.938, val loss = 1.062, average loss = 1.0
# epoch 39: train loss = 0.924, val loss = 1.06, average loss = 0.992
# epoch 40: train loss = 0.928, val loss = 1.044, average loss = 0.986
# epoch 41: train loss = 0.913, val loss = 1.054, average loss = 0.983
# epoch 42: train loss = 0.914, val loss = 1.086, average loss = 1.0
# epoch 43: train loss = 0.914, val loss = 1.045, average loss = 0.98
# epoch 44: train loss = 0.91, val loss = 1.057, average loss = 0.983
# epoch 45: train loss = 0.912, val loss = 1.07, average loss = 0.991
# epoch 46: train loss = 0.91, val loss = 1.046, average loss = 0.978
# epoch 47: train loss = 0.928, val loss = 1.065, average loss = 0.997
# epoch 48: train loss = 0.907, val loss = 1.054, average loss = 0.98
# epoch 49: train loss = 0.917, val loss = 1.111, average loss = 1.014
# epoch 50: train loss = 0.933, val loss = 1.08, average loss = 1.007
# FOLD 3:
# epoch 1: train loss = 0.943, val loss = 1.005, average loss = 0.974
# epoch 2: train loss = 0.933, val loss = 0.935, average loss = 0.934
# epoch 3: train loss = 0.937, val loss = 0.932, average loss = 0.935
# epoch 4: train loss = 0.951, val loss = 0.946, average loss = 0.949
# epoch 5: train loss = 0.936, val loss = 0.936, average loss = 0.936
# epoch 6: train loss = 0.946, val loss = 1.016, average loss = 0.981
# epoch 7: train loss = 0.961, val loss = 0.96, average loss = 0.96
# epoch 8: train loss = 0.929, val loss = 0.945, average loss = 0.937
# epoch 9: train loss = 0.925, val loss = 0.986, average loss = 0.956
# epoch 10: train loss = 0.926, val loss = 0.975, average loss = 0.951
# epoch 11: train loss = 0.923, val loss = 0.948, average loss = 0.935
# epoch 12: train loss = 0.924, val loss = 0.94, average loss = 0.932
# epoch 13: train loss = 0.927, val loss = 0.978, average loss = 0.952
# epoch 14: train loss = 0.927, val loss = 0.972, average loss = 0.949
# epoch 15: train loss = 0.914, val loss = 0.953, average loss = 0.933
# epoch 16: train loss = 0.931, val loss = 0.956, average loss = 0.943
# epoch 17: train loss = 0.91, val loss = 0.958, average loss = 0.934
# epoch 18: train loss = 0.912, val loss = 0.963, average loss = 0.938
# epoch 19: train loss = 0.943, val loss = 0.961, average loss = 0.952
# epoch 20: train loss = 0.936, val loss = 0.957, average loss = 0.947
# epoch 21: train loss = 0.91, val loss = 1.024, average loss = 0.967
# epoch 22: train loss = 0.918, val loss = 0.981, average loss = 0.95
# epoch 23: train loss = 0.915, val loss = 0.974, average loss = 0.944
# epoch 24: train loss = 0.907, val loss = 0.96, average loss = 0.933
# epoch 25: train loss = 0.906, val loss = 0.963, average loss = 0.935
# epoch 26: train loss = 0.911, val loss = 0.983, average loss = 0.947
# epoch 27: train loss = 0.902, val loss = 1.017, average loss = 0.96
# epoch 28: train loss = 0.906, val loss = 0.98, average loss = 0.943
# epoch 29: train loss = 0.907, val loss = 0.958, average loss = 0.932
# epoch 30: train loss = 0.899, val loss = 0.958, average loss = 0.929
# epoch 31: train loss = 0.896, val loss = 0.952, average loss = 0.924
# epoch 32: train loss = 0.904, val loss = 0.965, average loss = 0.934
# epoch 33: train loss = 0.906, val loss = 0.972, average loss = 0.939
# epoch 34: train loss = 0.893, val loss = 0.951, average loss = 0.922
# epoch 35: train loss = 0.895, val loss = 0.954, average loss = 0.925
# epoch 36: train loss = 0.895, val loss = 0.983, average loss = 0.939
# epoch 37: train loss = 0.886, val loss = 0.983, average loss = 0.935
# epoch 38: train loss = 0.891, val loss = 1.013, average loss = 0.952
# epoch 39: train loss = 0.931, val loss = 1.017, average loss = 0.974
# epoch 40: train loss = 0.895, val loss = 0.986, average loss = 0.941
# epoch 41: train loss = 0.895, val loss = 0.99, average loss = 0.943
# epoch 42: train loss = 0.897, val loss = 0.996, average loss = 0.946
# epoch 43: train loss = 0.882, val loss = 1.019, average loss = 0.951
# epoch 44: train loss = 0.888, val loss = 1.024, average loss = 0.956
# epoch 45: train loss = 0.889, val loss = 0.996, average loss = 0.943
# epoch 46: train loss = 0.903, val loss = 0.997, average loss = 0.95
# epoch 47: train loss = 0.873, val loss = 1.006, average loss = 0.94
# epoch 48: train loss = 0.874, val loss = 1.009, average loss = 0.942
# epoch 49: train loss = 0.873, val loss = 1.008, average loss = 0.941
# epoch 50: train loss = 0.879, val loss = 1.032, average loss = 0.955
# FOLD 4:
# epoch 1: train loss = 0.938, val loss = 0.839, average loss = 0.889
# epoch 2: train loss = 0.918, val loss = 0.839, average loss = 0.878
# epoch 3: train loss = 0.932, val loss = 0.854, average loss = 0.893
# epoch 4: train loss = 0.912, val loss = 0.85, average loss = 0.881
# epoch 5: train loss = 0.914, val loss = 0.839, average loss = 0.877
# epoch 6: train loss = 0.91, val loss = 0.818, average loss = 0.864
# epoch 7: train loss = 0.897, val loss = 0.872, average loss = 0.885
# epoch 8: train loss = 0.904, val loss = 0.849, average loss = 0.877
# epoch 9: train loss = 0.933, val loss = 0.977, average loss = 0.955
# epoch 10: train loss = 0.919, val loss = 0.883, average loss = 0.901
# epoch 11: train loss = 0.935, val loss = 0.847, average loss = 0.891
# epoch 12: train loss = 0.91, val loss = 0.848, average loss = 0.879
# epoch 13: train loss = 0.905, val loss = 0.884, average loss = 0.895
# epoch 14: train loss = 0.917, val loss = 0.894, average loss = 0.905
# epoch 15: train loss = 0.918, val loss = 0.84, average loss = 0.879
# epoch 16: train loss = 0.889, val loss = 0.892, average loss = 0.891
# epoch 17: train loss = 0.896, val loss = 0.884, average loss = 0.89
# epoch 18: train loss = 0.887, val loss = 0.858, average loss = 0.873
# epoch 19: train loss = 0.896, val loss = 0.874, average loss = 0.885
# epoch 20: train loss = 0.897, val loss = 0.878, average loss = 0.888
# epoch 21: train loss = 0.879, val loss = 0.874, average loss = 0.876
# epoch 22: train loss = 0.916, val loss = 0.957, average loss = 0.936
# epoch 23: train loss = 0.922, val loss = 0.893, average loss = 0.908
# epoch 24: train loss = 0.865, val loss = 0.874, average loss = 0.87
# epoch 25: train loss = 0.876, val loss = 0.929, average loss = 0.902
# epoch 26: train loss = 0.898, val loss = 0.903, average loss = 0.901
# epoch 27: train loss = 0.882, val loss = 0.913, average loss = 0.897
# epoch 28: train loss = 0.911, val loss = 0.857, average loss = 0.884
# epoch 29: train loss = 0.912, val loss = 0.89, average loss = 0.901
# epoch 30: train loss = 0.88, val loss = 0.887, average loss = 0.884
# epoch 31: train loss = 0.874, val loss = 0.9, average loss = 0.887
# epoch 32: train loss = 0.884, val loss = 0.881, average loss = 0.883
# epoch 33: train loss = 0.891, val loss = 0.887, average loss = 0.889
# epoch 34: train loss = 0.879, val loss = 0.888, average loss = 0.884
# epoch 35: train loss = 0.869, val loss = 0.868, average loss = 0.868
# epoch 36: train loss = 0.89, val loss = 0.883, average loss = 0.887
# epoch 37: train loss = 0.885, val loss = 0.872, average loss = 0.878
# epoch 38: train loss = 0.871, val loss = 0.866, average loss = 0.869
# epoch 39: train loss = 0.877, val loss = 0.913, average loss = 0.895
# epoch 40: train loss = 0.877, val loss = 0.904, average loss = 0.89
# epoch 41: train loss = 0.861, val loss = 0.894, average loss = 0.878
# epoch 42: train loss = 0.949, val loss = 0.902, average loss = 0.926
# epoch 43: train loss = 0.87, val loss = 0.913, average loss = 0.891
# epoch 44: train loss = 0.861, val loss = 0.926, average loss = 0.893
# epoch 45: train loss = 0.851, val loss = 0.926, average loss = 0.889
# epoch 46: train loss = 0.886, val loss = 0.902, average loss = 0.894
# epoch 47: train loss = 0.848, val loss = 0.929, average loss = 0.888
# epoch 48: train loss = 0.879, val loss = 0.879, average loss = 0.879
# epoch 49: train loss = 0.872, val loss = 0.913, average loss = 0.892
# epoch 50: train loss = 0.848, val loss = 0.908, average loss = 0.878
# FOLD 5:
# epoch 1: train loss = 0.894, val loss = 0.774, average loss = 0.834
# epoch 2: train loss = 0.893, val loss = 0.874, average loss = 0.883
# epoch 3: train loss = 0.889, val loss = 0.851, average loss = 0.87
# epoch 4: train loss = 0.916, val loss = 0.843, average loss = 0.88
# epoch 5: train loss = 0.88, val loss = 0.82, average loss = 0.85
# epoch 6: train loss = 0.853, val loss = 0.913, average loss = 0.883
# epoch 7: train loss = 0.873, val loss = 0.793, average loss = 0.833
# epoch 8: train loss = 0.875, val loss = 0.832, average loss = 0.854
# epoch 9: train loss = 0.878, val loss = 0.779, average loss = 0.828
# epoch 10: train loss = 0.864, val loss = 0.871, average loss = 0.868
# epoch 11: train loss = 0.874, val loss = 0.832, average loss = 0.853
# epoch 12: train loss = 0.855, val loss = 0.852, average loss = 0.854
# epoch 13: train loss = 0.85, val loss = 0.885, average loss = 0.867
# epoch 14: train loss = 0.859, val loss = 0.819, average loss = 0.839
# epoch 15: train loss = 0.848, val loss = 0.816, average loss = 0.832
# epoch 16: train loss = 0.837, val loss = 0.833, average loss = 0.835
# epoch 17: train loss = 0.829, val loss = 0.816, average loss = 0.823
# epoch 18: train loss = 0.843, val loss = 0.834, average loss = 0.838
# epoch 19: train loss = 0.863, val loss = 0.828, average loss = 0.845
# epoch 20: train loss = 0.843, val loss = 0.804, average loss = 0.824
# epoch 21: train loss = 0.832, val loss = 0.827, average loss = 0.829
# epoch 22: train loss = 0.858, val loss = 0.833, average loss = 0.846
# epoch 23: train loss = 0.845, val loss = 0.845, average loss = 0.845
# epoch 24: train loss = 0.897, val loss = 0.83, average loss = 0.864
# epoch 25: train loss = 0.873, val loss = 0.83, average loss = 0.852
# epoch 26: train loss = 0.892, val loss = 0.866, average loss = 0.879
# epoch 27: train loss = 0.914, val loss = 0.904, average loss = 0.909
# epoch 28: train loss = 0.939, val loss = 0.937, average loss = 0.938
# epoch 29: train loss = 0.947, val loss = 1.038, average loss = 0.992
# epoch 30: train loss = 0.993, val loss = 0.971, average loss = 0.982
# epoch 31: train loss = 0.963, val loss = 0.964, average loss = 0.964
# epoch 32: train loss = 0.962, val loss = 0.948, average loss = 0.955
# epoch 33: train loss = 0.916, val loss = 0.957, average loss = 0.937
# epoch 34: train loss = 0.916, val loss = 0.973, average loss = 0.944
# epoch 35: train loss = 0.891, val loss = 0.884, average loss = 0.888
# epoch 36: train loss = 0.861, val loss = 0.862, average loss = 0.862
# epoch 37: train loss = 0.853, val loss = 0.907, average loss = 0.88
# epoch 38: train loss = 0.839, val loss = 0.889, average loss = 0.864
# epoch 39: train loss = 0.867, val loss = 0.852, average loss = 0.86
# epoch 40: train loss = 0.837, val loss = 0.854, average loss = 0.846
# epoch 41: train loss = 0.83, val loss = 0.847, average loss = 0.838
# epoch 42: train loss = 0.836, val loss = 0.842, average loss = 0.839
# epoch 43: train loss = 0.828, val loss = 0.837, average loss = 0.833
# epoch 44: train loss = 0.822, val loss = 0.838, average loss = 0.83
# epoch 45: train loss = 0.822, val loss = 0.84, average loss = 0.831
# epoch 46: train loss = 0.828, val loss = 0.903, average loss = 0.865
# epoch 47: train loss = 0.843, val loss = 0.969, average loss = 0.906
# epoch 48: train loss = 0.87, val loss = 0.826, average loss = 0.848
# epoch 49: train loss = 0.855, val loss = 0.854, average loss = 0.854
# epoch 50: train loss = 0.83, val loss = 0.834, average loss = 0.832
# The model for participant 1 has been saved
# Leaving participant 1 out
# (1) Confusion matrix:
#  [[1 2 0]
#  [0 4 0]
#  [0 0 0]]
# (2) micro F1 score = 0.71
# (3) Weighted F1 score = 0.67
# (4) Percentage Classification accuracy = 71.43%
# --------------------------------
# LEAVING PARTICIPANT 2 OUT:
# FOLD 1:
# epoch 1: train loss = 0.894, val loss = 0.832, average loss = 0.863
# epoch 2: train loss = 0.891, val loss = 0.913, average loss = 0.902
# epoch 3: train loss = 0.863, val loss = 0.787, average loss = 0.825
# epoch 4: train loss = 0.861, val loss = 0.803, average loss = 0.832
# epoch 5: train loss = 0.861, val loss = 0.851, average loss = 0.856
# epoch 6: train loss = 0.875, val loss = 0.785, average loss = 0.83
# epoch 7: train loss = 0.876, val loss = 0.857, average loss = 0.866
# epoch 8: train loss = 0.86, val loss = 0.787, average loss = 0.823
# epoch 9: train loss = 0.855, val loss = 0.795, average loss = 0.825
# epoch 10: train loss = 0.922, val loss = 0.837, average loss = 0.88
# epoch 11: train loss = 0.868, val loss = 0.81, average loss = 0.839
# epoch 12: train loss = 0.875, val loss = 0.828, average loss = 0.852
# epoch 13: train loss = 0.851, val loss = 0.887, average loss = 0.869
# epoch 14: train loss = 0.852, val loss = 0.798, average loss = 0.825
# epoch 15: train loss = 0.846, val loss = 0.817, average loss = 0.832
# epoch 16: train loss = 0.882, val loss = 0.817, average loss = 0.849
# epoch 17: train loss = 0.839, val loss = 0.809, average loss = 0.824
# epoch 18: train loss = 0.859, val loss = 0.838, average loss = 0.849
# epoch 19: train loss = 0.862, val loss = 0.819, average loss = 0.84
# epoch 20: train loss = 0.839, val loss = 0.792, average loss = 0.815
# epoch 21: train loss = 0.857, val loss = 0.838, average loss = 0.848
# epoch 22: train loss = 0.831, val loss = 0.822, average loss = 0.826
# epoch 23: train loss = 0.838, val loss = 0.824, average loss = 0.831
# epoch 24: train loss = 0.833, val loss = 0.867, average loss = 0.85
# epoch 25: train loss = 0.828, val loss = 0.842, average loss = 0.835
# epoch 26: train loss = 0.841, val loss = 0.84, average loss = 0.84
# epoch 27: train loss = 0.846, val loss = 0.877, average loss = 0.862
# epoch 28: train loss = 0.83, val loss = 0.845, average loss = 0.838
# epoch 29: train loss = 0.846, val loss = 0.852, average loss = 0.849
# epoch 30: train loss = 0.836, val loss = 0.871, average loss = 0.854
# epoch 31: train loss = 0.837, val loss = 0.87, average loss = 0.854
# epoch 32: train loss = 0.819, val loss = 0.863, average loss = 0.841
# epoch 33: train loss = 0.818, val loss = 0.866, average loss = 0.842
# epoch 34: train loss = 0.817, val loss = 0.863, average loss = 0.84
# epoch 35: train loss = 0.817, val loss = 0.864, average loss = 0.841
# epoch 36: train loss = 0.817, val loss = 0.862, average loss = 0.84
# epoch 37: train loss = 0.817, val loss = 0.862, average loss = 0.84
# epoch 38: train loss = 0.817, val loss = 0.86, average loss = 0.839
# epoch 39: train loss = 0.817, val loss = 0.862, average loss = 0.84
# epoch 40: train loss = 0.817, val loss = 0.858, average loss = 0.838
# epoch 41: train loss = 0.817, val loss = 0.862, average loss = 0.84
# epoch 42: train loss = 0.817, val loss = 0.859, average loss = 0.838
# epoch 43: train loss = 0.817, val loss = 0.862, average loss = 0.839
# epoch 44: train loss = 0.817, val loss = 0.86, average loss = 0.839
# epoch 45: train loss = 0.817, val loss = 0.861, average loss = 0.839
# epoch 46: train loss = 0.817, val loss = 0.86, average loss = 0.838
# epoch 47: train loss = 0.817, val loss = 0.864, average loss = 0.84
# epoch 48: train loss = 0.817, val loss = 0.86, average loss = 0.839
# epoch 49: train loss = 0.817, val loss = 0.863, average loss = 0.84
# epoch 50: train loss = 0.817, val loss = 0.86, average loss = 0.838
# FOLD 2:
# epoch 1: train loss = 0.82, val loss = 0.908, average loss = 0.864
# epoch 2: train loss = 0.813, val loss = 0.918, average loss = 0.866
# epoch 3: train loss = 0.808, val loss = 0.891, average loss = 0.849
# epoch 4: train loss = 0.799, val loss = 0.899, average loss = 0.849
# epoch 5: train loss = 0.804, val loss = 0.897, average loss = 0.851
# epoch 6: train loss = 0.802, val loss = 0.896, average loss = 0.849
# epoch 7: train loss = 0.833, val loss = 0.932, average loss = 0.883
# epoch 8: train loss = 0.826, val loss = 0.935, average loss = 0.88
# epoch 9: train loss = 0.849, val loss = 0.974, average loss = 0.912
# epoch 10: train loss = 0.823, val loss = 0.913, average loss = 0.868
# epoch 11: train loss = 0.798, val loss = 0.907, average loss = 0.853
# epoch 12: train loss = 0.793, val loss = 0.966, average loss = 0.879
# epoch 13: train loss = 0.805, val loss = 0.911, average loss = 0.858
# epoch 14: train loss = 0.802, val loss = 0.931, average loss = 0.866
# epoch 15: train loss = 0.824, val loss = 0.925, average loss = 0.875
# epoch 16: train loss = 0.798, val loss = 0.914, average loss = 0.856
# epoch 17: train loss = 0.801, val loss = 0.919, average loss = 0.86
# epoch 18: train loss = 0.802, val loss = 0.924, average loss = 0.863
# epoch 19: train loss = 0.787, val loss = 0.941, average loss = 0.864
# epoch 20: train loss = 0.794, val loss = 0.912, average loss = 0.853
# epoch 21: train loss = 0.799, val loss = 0.909, average loss = 0.854
# epoch 22: train loss = 0.803, val loss = 0.942, average loss = 0.872
# epoch 23: train loss = 0.805, val loss = 0.938, average loss = 0.871
# epoch 24: train loss = 0.788, val loss = 0.915, average loss = 0.852
# epoch 25: train loss = 0.789, val loss = 0.911, average loss = 0.85
# epoch 26: train loss = 0.786, val loss = 0.911, average loss = 0.849
# epoch 27: train loss = 0.802, val loss = 0.921, average loss = 0.861
# epoch 28: train loss = 0.808, val loss = 0.946, average loss = 0.877
# epoch 29: train loss = 0.802, val loss = 0.929, average loss = 0.865
# epoch 30: train loss = 0.812, val loss = 0.921, average loss = 0.866
# epoch 31: train loss = 0.795, val loss = 1.0, average loss = 0.897
# epoch 32: train loss = 0.804, val loss = 0.935, average loss = 0.869
# epoch 33: train loss = 0.814, val loss = 1.01, average loss = 0.912
# epoch 34: train loss = 0.802, val loss = 0.926, average loss = 0.864
# epoch 35: train loss = 0.799, val loss = 0.927, average loss = 0.863
# epoch 36: train loss = 0.788, val loss = 0.953, average loss = 0.871
# epoch 37: train loss = 0.796, val loss = 0.952, average loss = 0.874
# epoch 38: train loss = 0.791, val loss = 0.948, average loss = 0.87
# epoch 39: train loss = 0.791, val loss = 0.934, average loss = 0.862
# epoch 40: train loss = 0.785, val loss = 0.95, average loss = 0.868
# epoch 41: train loss = 0.787, val loss = 0.924, average loss = 0.855
# epoch 42: train loss = 0.783, val loss = 0.926, average loss = 0.854
# epoch 43: train loss = 0.783, val loss = 0.926, average loss = 0.854
# epoch 44: train loss = 0.783, val loss = 0.925, average loss = 0.854
# epoch 45: train loss = 0.782, val loss = 0.928, average loss = 0.855
# epoch 46: train loss = 0.784, val loss = 0.918, average loss = 0.851
# epoch 47: train loss = 0.783, val loss = 0.919, average loss = 0.851
# epoch 48: train loss = 0.782, val loss = 0.918, average loss = 0.85
# epoch 49: train loss = 0.782, val loss = 0.918, average loss = 0.85
# epoch 50: train loss = 0.782, val loss = 0.918, average loss = 0.85
# FOLD 3:
# epoch 1: train loss = 0.809, val loss = 0.863, average loss = 0.836
# epoch 2: train loss = 0.812, val loss = 0.856, average loss = 0.834
# epoch 3: train loss = 0.81, val loss = 0.849, average loss = 0.829
# epoch 4: train loss = 0.809, val loss = 0.859, average loss = 0.834
# epoch 5: train loss = 0.814, val loss = 0.855, average loss = 0.835
# epoch 6: train loss = 0.8, val loss = 0.86, average loss = 0.83
# epoch 7: train loss = 0.801, val loss = 0.896, average loss = 0.848
# epoch 8: train loss = 0.812, val loss = 0.851, average loss = 0.831
# epoch 9: train loss = 0.815, val loss = 0.919, average loss = 0.867
# epoch 10: train loss = 0.818, val loss = 0.925, average loss = 0.872
# epoch 11: train loss = 0.842, val loss = 0.904, average loss = 0.873
# epoch 12: train loss = 0.837, val loss = 0.875, average loss = 0.856
# epoch 13: train loss = 0.871, val loss = 0.85, average loss = 0.86
# epoch 14: train loss = 0.821, val loss = 0.896, average loss = 0.858
# epoch 15: train loss = 0.826, val loss = 0.883, average loss = 0.854
# epoch 16: train loss = 0.814, val loss = 0.864, average loss = 0.839
# epoch 17: train loss = 0.807, val loss = 0.851, average loss = 0.829
# epoch 18: train loss = 0.804, val loss = 0.868, average loss = 0.836
# epoch 19: train loss = 0.815, val loss = 0.852, average loss = 0.834
# epoch 20: train loss = 0.808, val loss = 0.909, average loss = 0.859
# epoch 21: train loss = 0.805, val loss = 0.862, average loss = 0.834
# epoch 22: train loss = 0.807, val loss = 0.859, average loss = 0.833
# epoch 23: train loss = 0.811, val loss = 0.865, average loss = 0.838
# epoch 24: train loss = 0.801, val loss = 0.863, average loss = 0.832
# epoch 25: train loss = 0.804, val loss = 0.862, average loss = 0.833
# epoch 26: train loss = 0.802, val loss = 0.86, average loss = 0.831
# epoch 27: train loss = 0.8, val loss = 0.865, average loss = 0.832
# epoch 28: train loss = 0.804, val loss = 0.87, average loss = 0.837
# epoch 29: train loss = 0.799, val loss = 0.881, average loss = 0.84
# epoch 30: train loss = 0.798, val loss = 0.855, average loss = 0.826
# epoch 31: train loss = 0.792, val loss = 0.856, average loss = 0.824
# epoch 32: train loss = 0.792, val loss = 0.859, average loss = 0.825
# epoch 33: train loss = 0.792, val loss = 0.858, average loss = 0.825
# epoch 34: train loss = 0.792, val loss = 0.859, average loss = 0.825
# epoch 35: train loss = 0.792, val loss = 0.859, average loss = 0.825
# epoch 36: train loss = 0.792, val loss = 0.858, average loss = 0.825
# epoch 37: train loss = 0.792, val loss = 0.859, average loss = 0.825
# epoch 38: train loss = 0.792, val loss = 0.856, average loss = 0.824
# epoch 39: train loss = 0.792, val loss = 0.859, average loss = 0.825
# epoch 40: train loss = 0.791, val loss = 0.857, average loss = 0.824
# epoch 41: train loss = 0.792, val loss = 0.858, average loss = 0.825
# epoch 42: train loss = 0.791, val loss = 0.859, average loss = 0.825
# epoch 43: train loss = 0.792, val loss = 0.859, average loss = 0.826
# epoch 44: train loss = 0.791, val loss = 0.859, average loss = 0.825
# epoch 45: train loss = 0.792, val loss = 0.858, average loss = 0.825
# epoch 46: train loss = 0.791, val loss = 0.859, average loss = 0.825
# epoch 47: train loss = 0.791, val loss = 0.86, average loss = 0.825
# epoch 48: train loss = 0.792, val loss = 0.86, average loss = 0.826
# epoch 49: train loss = 0.791, val loss = 0.858, average loss = 0.825
# epoch 50: train loss = 0.791, val loss = 0.859, average loss = 0.825
# FOLD 4:
# epoch 1: train loss = 0.814, val loss = 0.77, average loss = 0.792
# epoch 2: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 3: train loss = 0.811, val loss = 0.77, average loss = 0.791
# epoch 4: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 5: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 6: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 7: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 8: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 9: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 10: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 11: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 12: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 13: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 14: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 15: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 16: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 17: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 18: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 19: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 20: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 21: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 22: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 23: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 24: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 25: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 26: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 27: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 28: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 29: train loss = 0.811, val loss = 0.77, average loss = 0.791
# epoch 30: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 31: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 32: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 33: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 34: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 35: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 36: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 37: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 38: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 39: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 40: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 41: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 42: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 43: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 44: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 45: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 46: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 47: train loss = 0.81, val loss = 0.77, average loss = 0.79
# epoch 48: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 49: train loss = 0.811, val loss = 0.77, average loss = 0.79
# epoch 50: train loss = 0.81, val loss = 0.77, average loss = 0.79
# FOLD 5:
# epoch 1: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 2: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 3: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 4: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 5: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 6: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 7: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 8: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 9: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 10: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 11: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 12: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 13: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 14: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 15: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 16: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 17: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 18: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 19: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 20: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 21: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 22: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 23: train loss = 0.817, val loss = 0.742, average loss = 0.78
# epoch 24: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 25: train loss = 0.817, val loss = 0.743, average loss = 0.78
# epoch 26: train loss = 0.82, val loss = 0.758, average loss = 0.789
# epoch 27: train loss = 0.839, val loss = 0.746, average loss = 0.792
# epoch 28: train loss = 0.818, val loss = 0.746, average loss = 0.782
# epoch 29: train loss = 0.86, val loss = 0.755, average loss = 0.808
# epoch 30: train loss = 0.828, val loss = 0.746, average loss = 0.787
# epoch 31: train loss = 0.817, val loss = 0.752, average loss = 0.784
# epoch 32: train loss = 0.818, val loss = 0.755, average loss = 0.786
# epoch 33: train loss = 0.84, val loss = 0.783, average loss = 0.811
# epoch 34: train loss = 0.824, val loss = 0.766, average loss = 0.795
# epoch 35: train loss = 0.819, val loss = 0.757, average loss = 0.788
# epoch 36: train loss = 0.818, val loss = 0.759, average loss = 0.788
# epoch 37: train loss = 0.817, val loss = 0.762, average loss = 0.789
# epoch 38: train loss = 0.817, val loss = 0.759, average loss = 0.788
# epoch 39: train loss = 0.818, val loss = 0.748, average loss = 0.783
# epoch 40: train loss = 0.818, val loss = 0.757, average loss = 0.788
# epoch 41: train loss = 0.817, val loss = 0.755, average loss = 0.786
# epoch 42: train loss = 0.821, val loss = 0.757, average loss = 0.789
# epoch 43: train loss = 0.818, val loss = 0.758, average loss = 0.788
# epoch 44: train loss = 0.817, val loss = 0.761, average loss = 0.789
# epoch 45: train loss = 0.83, val loss = 0.756, average loss = 0.793
# epoch 46: train loss = 0.816, val loss = 0.763, average loss = 0.79
# epoch 47: train loss = 0.817, val loss = 0.756, average loss = 0.787
# epoch 48: train loss = 0.814, val loss = 0.754, average loss = 0.784
# epoch 49: train loss = 0.814, val loss = 0.757, average loss = 0.785
# epoch 50: train loss = 0.814, val loss = 0.754, average loss = 0.784
# The model for participant 2 has been saved
# Leaving participant 2 out
# (1) Confusion matrix:
#  [[0 2 0]
#  [0 5 0]
#  [0 0 0]]
# (2) micro F1 score = 0.71
# (3) Weighted F1 score = 0.6
# (4) Percentage Classification accuracy = 71.43%
# --------------------------------
# LEAVING PARTICIPANT 3 OUT:
# FOLD 1:
# epoch 1: train loss = 0.827, val loss = 0.807, average loss = 0.817
# epoch 2: train loss = 0.824, val loss = 0.809, average loss = 0.816
# epoch 3: train loss = 0.821, val loss = 0.807, average loss = 0.814
# epoch 4: train loss = 0.821, val loss = 0.807, average loss = 0.814
train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 2: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 3: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 4: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 5: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 6: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 7: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 8: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 9: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 10: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 11: train loss = 0.788, val loss = 0.938, average loss = 0.863
# epoch 12: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 13: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 14: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 15: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 16: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 17: train loss = 0.788, val loss = 0.937, average loss = 0.862
# epoch 18: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 19: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 20: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 21: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 22: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 23: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 24: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 25: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 26: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 27: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 28: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 29: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 30: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 31: train loss = 0.788, val loss = 0.937, average loss = 0.863
# epoch 32: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 33: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 34: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 35: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 36: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 37: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 38: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 39: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 40: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 41: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 42: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 43: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 44: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 45: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 46: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 47: train loss = 0.788, val loss = 0.936, average loss = 0.862
# epoch 48: train loss = 0.788, val loss = 0.935, average loss = 0.861
# epoch 49: train loss = 0.788, val loss = 0.935, average loss = 0.862
# epoch 50: train loss = 0.788, val loss = 0.935, average loss = 0.862
# FOLD 3:
# epoch 1: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 2: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 3: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 4: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 5: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 6: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 7: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 8: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 9: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 10: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 11: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 12: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 13: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 14: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 15: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 16: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 17: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 18: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 19: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 20: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 21: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 22: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 23: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 24: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 25: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 26: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 27: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 28: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 29: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 30: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 31: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 32: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 33: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 34: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 35: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 36: train loss = 0.81, val loss = 0.846, average loss = 0.828
# epoch 37: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 38: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 39: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 40: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 41: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 42: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 43: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 44: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 45: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 46: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 47: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 48: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 49: train loss = 0.81, val loss = 0.847, average loss = 0.828
# epoch 50: train loss = 0.81, val loss = 0.847, average loss = 0.828
# FOLD 4:
# epoch 1: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 2: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 3: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 4: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 5: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 6: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 7: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 8: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 9: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 10: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 11: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 12: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 13: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 14: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 15: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 16: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 17: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 18: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 19: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 20: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 21: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 22: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 23: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 24: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 25: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 26: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 27: train loss = 0.833, val loss = 0.756, average loss = 0.795
# epoch 28: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 29: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 30: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 31: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 32: train loss = 0.833, val loss = 0.756, average loss = 0.794
# epoch 33: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 34: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 35: train loss = 0.833, val loss = 0.757, average loss = 0.795
# epoch 36: train loss = 0.833, val loss = 0.758, average loss = 0.795
# epoch 37: train loss = 0.832, val loss = 0.766, average loss = 0.799
# epoch 38: train loss = 0.833, val loss = 0.758, average loss = 0.795
# epoch 39: train loss = 0.833, val loss = 0.763, average loss = 0.798
# epoch 40: train loss = 0.833, val loss = 0.758, average loss = 0.795
# epoch 41: train loss = 0.832, val loss = 0.763, average loss = 0.798
# epoch 42: train loss = 0.833, val loss = 0.758, average loss = 0.795
# ...
# epoch 23: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 24: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 25: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 26: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 27: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 28: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 29: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 30: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 31: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 32: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 33: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch 34: train loss = 0.78, val loss = 0.834, average loss = 0.807
# epoch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2l/2jbt3sns75nf0k4xsrp2zvy00000gn/T/ipykernel_19455/1554543268.py in <cell line: 1>()
# ----> 1 dtryftugyihuoi
#
# NameError: name 'dtryftugyihuoi' is not defined

# %%
def find_best_model_for_fold_4(train_dataloader, val_dataloader, learning_rate, num_epochs):

    # Model
    train_model = LSTM_2()

    # Loss and Optimiser
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(train_model.parameters(), lr=learning_rate, momentum=0.7)

    best_avg_loss = np.inf
    best_model = None
    #best_model_epoch_num = np.inf
    train_loss_lst = []
    val_loss_lst = []
    avg_loss_lst = []

    for epoch in range(num_epochs):  # loop over the dataset multiple times

        #Set the model in training mode
        train_model.train()

        # Initialise the total training and validation loss
        epoch_train_loss = 0
        epoch_val_loss = 0
        avg_loss = 0
        #count_train = 0
        #count_val = 0

        #running_loss = 0.0
        for i, train_data in enumerate(train_dataloader, 0):
            #print(len(train_data))
            #count_train += 1
            # get the inputs; data is a list of [input1, input2, label]
            train_input1, train_input2, train_labels = train_data #train_input2, 

            #train_labels = train_labels.type(torch.LongTensor)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            train_preds = train_model(train_input1, train_input2)  
            #print(train_labels)#

            train_loss = criterion(train_preds, train_labels)
            train_loss.backward()
            optimizer.step()

            # Update training loss
            epoch_train_loss += train_loss.item()

        # Switch off auto grad for evaluation
        with torch.no_grad():

            # Set the model in evaluation mode
            train_model.eval()

            for j, val_data in enumerate(val_dataloader, 0):
               # count_val += 1
               # print(len(val_data))
            # get the inputs; data is a list of [input1, input2, label]
                val_input1, val_input2, val_labels = val_data # val_input2, 

                #val_labels = val_labels.type(torch.LongTensor)

                val_preds = train_model(val_input1, val_input2) #, val_input2

                # Update validation loss
                val_loss = criterion(val_preds, val_labels)

                epoch_val_loss += val_loss.item()
        #print(len(train_dataloader), len(val_dataloader))       
        avg_training_loss = epoch_train_loss / len(train_dataloader) #count_train
        avg_validation_loss = epoch_val_loss / len(val_dataloader) #count_val
        avg_loss = (avg_training_loss + avg_validation_loss) / 2
        
        train_loss_lst.append(avg_training_loss)
        val_loss_lst.append(avg_validation_loss)
        avg_loss_lst.append(avg_loss)
         
        #print(f'epoch {epoch+1}: train loss = {round(avg_training_loss,2)}, val loss = {round(avg_validation_loss,2)}, average loss = {round(avg_loss,2)}')

        if avg_loss < best_avg_loss:
            best_avg_loss = avg_loss
            best_model = train_model.state_dict()

    return best_avg_loss, best_model, train_loss_lst, val_loss_lst, avg_loss_lst   #, avg_loss_lst,

# %%
# Original
def LSTM_LOP0CV_properties_2(data_0, data_1, num_folds=5, predicting_feature='property_id', learning_rate=0.01, num_epochs=10, random_state=num): #, num_inner_folds=5
    # Set fixed random number seed
    torch.manual_seed(num)
    
   # elif predicting_feature == 'rating_level_num':
    #weighted_f1_lst = [] 
    total_conf_mat = 0
    micro_f1_lst = []
    macro_f1_lst = []
    acc_lst = []

    #lst = [6,24,2]#,24]
    
    for participant in sorted(data_0.participant_id.unique()): # #:lst: #
        print(f'LEAVING PARTICIPANT {participant} OUT:')
        
        # Split the data into training and testing
        training_data_0 = data_0[data_0.participant_id != participant] 
        training_data_1 = data_1[data_1.participant_id != participant] 
        testing_data_0 = data_0[data_0.participant_id == participant] 
        testing_data_1 = data_1[data_1.participant_id == participant] 

        # Data preparation
        X_train_0 = create_X_3d(training_data_0, 11)
        X_train_1 = create_X_3d(training_data_1, 11)        
        y_train = create_y_train_for_3d_X(training_data_0, predicting_feature = 'property_id')
        X_test_0 = create_X_3d(testing_data_0, 11) 
        X_test_1 = create_X_3d(testing_data_1, 11)
        y_test = create_y_test_for_3d_X(testing_data_0, predicting_feature = 'property_id')
        #print(y_test)

        #print(X_train_0.shape)
        #print(X_train_1.shape)
        #print(y_train.shape)
        #print(X_test_0.shape)
        #print(X_test_1.shape)
        #print(y_test.shape)
 
        # Create the datasets and dataloaders
        train_dataset = TensorDataset(X_train_0, X_train_1, y_train) 
        
        test_dataset = TensorDataset(X_test_0, X_test_1, y_test)
        test_dataloader = torch.utils.data.DataLoader(test_dataset, shuffle=True, batch_size=30) # num_workers=2,       
            
        # Configure the cross-validation procedure
        cv_inner = KFold(n_splits=num_folds, shuffle=True, random_state=num)
                
        min_avg_loss_subject = np.inf
        best_model_subject = None
        
        best_train_loss_lst = None
        best_val_loss_lst = None
        best_avg_loss_lst = None
        best_fold = np.inf

        for fold, (train_ids, val_ids) in enumerate(cv_inner.split(train_dataset)):
            #print(f'FOLD {fold+1}:')
                       
            # Sample elements randomly from a given list of ids, no replacement.
            train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids) # The ids are the same for both
            val_subsampler = torch.utils.data.SubsetRandomSampler(val_ids)

            # Define data loaders for training and testing data in this fold
            train_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=train_subsampler) #, batch_size=100
            val_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=val_subsampler) #, batch_size=20        

            avg_loss_fold, best_model_fold, fold_train_loss_lst, fold_val_loss_lst, fold_avg_loss_lst = find_best_model_for_fold_4(train_dataloader, val_dataloader, learning_rate, num_epochs)
                           
            if avg_loss_fold < min_avg_loss_subject:
                min_avg_loss_subject = avg_loss_fold
                best_model_subject = best_model_fold
                best_train_loss_lst = fold_train_loss_lst
                best_val_loss_lst = fold_val_loss_lst
                best_avg_loss_lst = fold_avg_loss_lst
                best_fold = fold+1

        fig = plt.figure(f"{participant}")                  
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_train_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_val_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_avg_loss_lst)
        plt.title(f"Loss when participant {participant} is left out for fold {best_fold} (lr={learning_rate}, num_epochs ={num_epochs})")
        plt.legend(['train loss', 'val loss', 'avg_loss'])

        # save trained model 
        name = 'model_participant_'+str(participant)+'.pt'
        torch.save(best_model_subject, name)
        print(f'The model for participant {participant} has been saved')
        
        test_model = LSTM_2()
        test_model.load_state_dict(torch.load(name))

        dataiter = iter(test_dataloader) 
        test_input1, test_input2, test_labels = dataiter.next() 
    
        test_preds = test_model(test_input1, test_input2) 
        
        test_preds_np = test_preds.detach().numpy()
        test_predicted_np = np.argmax(test_preds_np, axis = 1)
        
        test_labels_np = test_labels.numpy()       
        

        conf_mat = confusion_matrix(test_labels_np, test_predicted_np, labels=[0, 1, 2, 3, 4])
        macro_f1_score = f1_score(test_labels_np, test_predicted_np, average='macro') 
        micro_f1_score = f1_score(test_labels_np, test_predicted_np, average='micro')  
        acc = accuracy_score(test_labels_np, test_predicted_np)

        print(f"Leaving participant {participant} out")
        print("(1) Confusion matrix:\n", conf_mat)
        print(f"(2) micro F1 score = {round(micro_f1_score,2)}")
        print(f"(3) macro F1 score = {round(macro_f1_score,2)}")    
        print(f"(4) Percentage Classification accuracy = {round(acc*100,2)}%")
        
        total_conf_mat += conf_mat 
        micro_f1_lst.append(micro_f1_score)
        macro_f1_lst.append(macro_f1_score) 
        acc_lst.append(acc)
        print('--------------------------------')
        
    avg_micro_f1_score = sum(micro_f1_lst) / len(micro_f1_lst)
    avg_macro_f1_score = sum(macro_f1_lst) / len(macro_f1_lst)         
    avg_acc = sum(acc_lst) / len(acc_lst)   
    
    print(f'Using Leave One Participant Out CV (LOPOCV):') 
    print("(1) Confusion matrix:\n", total_conf_mat)
    print(f"(2) Average micro F1 score = {round(avg_micro_f1_score,2)}")
    #if predicting_feature == 'property_id':
    print(f"(3) Average macro F1 score = {round(avg_macro_f1_score,2)}")
    #elif predicting_feature == 'rating_level_num':
        #print(f"(3) Average weighted F1 score = {round(avg_weighted_f1_score,2)}")      
    print(f"(4) Average Percentage Classification accuracy = {round(avg_acc*100,2)}%")

# %%
LSTM_LOP0CV_properties_2(emg_0, emg_1, num_folds=5, predicting_feature='property_id', learning_rate=0.05, num_epochs=70, random_state=num)

# %%
t2 = time.time()

# %% [markdown]
# ## Model 5 - CNN + LSTM

# %%
complete_emg = normalised_df.iloc[:,:59]
hand0_emg = normalised_df.iloc[:,43:51]
hand0_emg.head()

# %%
hand0_emg = normalised_df.iloc[:,19:27]
hand1_emg = normalised_df.iloc[:,43:51]

emg_0 = pd.concat([df_info, hand0_emg], axis=1)
emg_1 = pd.concat([df_info, hand1_emg], axis=1)

# %% [markdown]
# ### Create the model

# %%
class CNN_LSTM(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=1, stride=1, padding=0, groups=3) # Change kernel size to 3
        self.pool = nn.MaxPool1d(1, 1) # Change kernel size to 1 and stride to 1
        self.rnn = nn.LSTM(8, 4, 1, batch_first=True)
        #self.h0 = torch.randn(1, 50, 7)
        #self.c0 = torch.randn(1, 50, 7)
        self.fc1 = nn.Linear(3 * 4 * 2, 18)
        self.fc2 = nn.Linear(18, 10)
        self.fc3 = nn.Linear(10, 5)
          
    def forward(self, x1, x2): #, x2
        x1 = self.pool(F.tanh(self.conv1(x1))) # Use tanh instead?
        x2 = self.pool(F.tanh(self.conv1(x2))) # Use tanh instead?
        
        #x = self.pool(F.relu(self.conv2(x)))
        x1, (hn, cn) = self.rnn(x1) #, (self.h0, self.c0)
        x1 = F.tanh(x1)
        x2, (hm, cm) = self.rnn(x2) # (self.h0, self.c0)
        x2 = F.tanh(x2)
        
        x = torch.cat((x1, x2), 2)
        
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.tanh(self.fc1(x))
        x = F.tanh(self.fc2(x))
        x = F.softmax(self.fc3(x), dim=1)
        return x

# %%
m3 = CNN_LSTM()
print(m3)

# %%
def find_best_model_for_fold_3(train_dataloader, val_dataloader, learning_rate, num_epochs):

    # Model
    train_model = CNN_LSTM()

    # Loss and Optimiser
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(train_model.parameters(), lr=learning_rate, momentum=0.7)

    best_avg_loss = np.inf
    best_model = None
    #best_model_epoch_num = np.inf
    train_loss_lst = []
    val_loss_lst = []
    avg_loss_lst = []

    for epoch in range(num_epochs):  # loop over the dataset multiple times

        #Set the model in training mode
        train_model.train()

        # Initialise the total training and validation loss
        epoch_train_loss = 0
        epoch_val_loss = 0
        avg_loss = 0
        #count_train = 0
        #count_val = 0

        #running_loss = 0.0
        for i, train_data in enumerate(train_dataloader, 0):
            #print(len(train_data))
            #count_train += 1
            # get the inputs; data is a list of [input1, input2, label]
            train_input1, train_input2, train_labels = train_data #train_input2, 

            #train_labels = train_labels.type(torch.LongTensor)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            train_preds = train_model(train_input1, train_input2)  
            #print(train_labels)#

            train_loss = criterion(train_preds, train_labels)
            train_loss.backward()
            optimizer.step()

            # Update training loss
            epoch_train_loss += train_loss.item()

        # Switch off auto grad for evaluation
        with torch.no_grad():

            # Set the model in evaluation mode
            train_model.eval()

            for j, val_data in enumerate(val_dataloader, 0):
               # count_val += 1
               # print(len(val_data))
            # get the inputs; data is a list of [input1, input2, label]
                val_input1, val_input2, val_labels = val_data # val_input2, 

                #val_labels = val_labels.type(torch.LongTensor)

                val_preds = train_model(val_input1, val_input2) #, val_input2

                # Update validation loss
                val_loss = criterion(val_preds, val_labels)

                epoch_val_loss += val_loss.item()
        #print(len(train_dataloader), len(val_dataloader))       
        avg_training_loss = epoch_train_loss / len(train_dataloader) #count_train
        avg_validation_loss = epoch_val_loss / len(val_dataloader) #count_val
        avg_loss = (avg_training_loss + avg_validation_loss) / 2
        
        train_loss_lst.append(avg_training_loss)
        val_loss_lst.append(avg_validation_loss)
        avg_loss_lst.append(avg_loss)
         
        print(f'epoch {epoch+1}: train loss = {round(avg_training_loss,2)}, val loss = {round(avg_validation_loss,2)}, average loss = {round(avg_loss,2)}')

        if avg_loss < best_avg_loss:
            best_avg_loss = avg_loss
            best_model = train_model.state_dict()

    return best_avg_loss, best_model, train_loss_lst, val_loss_lst, avg_loss_lst   #, avg_loss_lst,

# %%
# Original
def CNN_LSTM_LOP0CV_properties_1(data_0, data_1, num_folds=5, predicting_feature='property_id', learning_rate=0.01, num_epochs=10, random_state=num): #, num_inner_folds=5
    # Set fixed random number seed
    torch.manual_seed(num)
    
   # elif predicting_feature == 'rating_level_num':
    #weighted_f1_lst = [] 
    total_conf_mat = 0
    micro_f1_lst = []
    macro_f1_lst = []
    acc_lst = []

    lst = [6,24,2]#,24]
    
    for participant in lst: #sorted(data0.participant_id.unique()): # #:lst: #
        print(f'LEAVING PARTICIPANT {participant} OUT:')
        
        # Split the data into training and testing
        training_data_0 = data_0[data_0.participant_id != participant] 
        training_data_1 = data_1[data_1.participant_id != participant] 
        testing_data_0 = data_0[data_0.participant_id == participant] 
        testing_data_1 = data_1[data_1.participant_id == participant] 

        # Data preparation
        X_train_0 = create_X_3d(training_data_0, 11)
        X_train_1 = create_X_3d(training_data_1, 11)        
        y_train = create_y_train_for_3d_X(training_data_0, predicting_feature = 'property_id')
        X_test_0 = create_X_3d(testing_data_0, 11) 
        X_test_1 = create_X_3d(testing_data_1, 11)
        y_test = create_y_test_for_3d_X(testing_data_0, predicting_feature = 'property_id')
        #print(y_test)

        #print(X_train_0.shape)
        #print(X_train_1.shape)
        #print(y_train.shape)
        #print(X_test_0.shape)
        #print(X_test_1.shape)
        #print(y_test.shape)
 
        # Create the datasets and dataloaders
        train_dataset = TensorDataset(X_train_0, X_train_1, y_train) 
        
        test_dataset = TensorDataset(X_test_0, X_test_1, y_test)
        test_dataloader = torch.utils.data.DataLoader(test_dataset, shuffle=True, batch_size=30) # num_workers=2,       
            
        # Configure the cross-validation procedure
        cv_inner = KFold(n_splits=num_folds, shuffle=True, random_state=num)
                
        min_avg_loss_subject = np.inf
        best_model_subject = None
        
        best_train_loss_lst = None
        best_val_loss_lst = None
        best_avg_loss_lst = None
        best_fold = np.inf

        for fold, (train_ids, val_ids) in enumerate(cv_inner.split(train_dataset)):
            #print(f'FOLD {fold+1}:')
                       
            # Sample elements randomly from a given list of ids, no replacement.
            train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids) # The ids are the same for both
            val_subsampler = torch.utils.data.SubsetRandomSampler(val_ids)

            # Define data loaders for training and testing data in this fold
            train_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=train_subsampler) #, batch_size=100
            val_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=val_subsampler) #, batch_size=20        

            avg_loss_fold, best_model_fold, fold_train_loss_lst, fold_val_loss_lst, fold_avg_loss_lst = find_best_model_for_fold_3(train_dataloader, val_dataloader, learning_rate, num_epochs)
                           
            if avg_loss_fold < min_avg_loss_subject:
                min_avg_loss_subject = avg_loss_fold
                best_model_subject = best_model_fold
                best_train_loss_lst = fold_train_loss_lst
                best_val_loss_lst = fold_val_loss_lst
                best_avg_loss_lst = fold_avg_loss_lst
                best_fold = fold+1

        fig = plt.figure(f"{participant}")                  
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_train_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_val_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_avg_loss_lst)
        plt.title(f"Loss when participant {participant} is left out for fold {best_fold} (lr={learning_rate}, num_epochs ={num_epochs})")
        plt.legend(['train loss', 'val loss', 'avg_loss'])

        # save trained model 
        name = 'model_participant_'+str(participant)+'.pt'
        torch.save(best_model_subject, name)
        print(f'The model for participant {participant} has been saved')
        
        test_model = CNN_LSTM()
        test_model.load_state_dict(torch.load(name))

        dataiter = iter(test_dataloader) 
        test_input1, test_input2, test_labels = dataiter.next() 
    
        test_preds = test_model(test_input1, test_input2) 
        
        test_preds_np = test_preds.detach().numpy()
        test_predicted_np = np.argmax(test_preds_np, axis = 1)
        
        test_labels_np = test_labels.numpy()       
        

        conf_mat = confusion_matrix(test_labels_np, test_predicted_np, labels=[0, 1, 2, 3, 4])
        macro_f1_score = f1_score(test_labels_np, test_predicted_np, average='macro') 
        micro_f1_score = f1_score(test_labels_np, test_predicted_np, average='micro')  
        acc = accuracy_score(test_labels_np, test_predicted_np)

        print(f"Leaving participant {participant} out")
        print("(1) Confusion matrix:\n", conf_mat)
        print(f"(2) micro F1 score = {round(micro_f1_score,2)}")
        print(f"(3) macro F1 score = {round(macro_f1_score,2)}")    
        print(f"(4) Percentage Classification accuracy = {round(acc*100,2)}%")
        
        total_conf_mat += conf_mat 
        micro_f1_lst.append(micro_f1_score)
        macro_f1_lst.append(macro_f1_score) 
        acc_lst.append(acc)
        print('--------------------------------')
        
    avg_micro_f1_score = sum(micro_f1_lst) / len(micro_f1_lst)
    avg_macro_f1_score = sum(macro_f1_lst) / len(macro_f1_lst)         
    avg_acc = sum(acc_lst) / len(acc_lst)   
    
    print(f'Using Leave One Participant Out CV (LOPOCV):') 
    print("(1) Confusion matrix:\n", total_conf_mat)
    print(f"(2) Average micro F1 score = {round(avg_micro_f1_score,2)}")
    #if predicting_feature == 'property_id':
    print(f"(3) Average macro F1 score = {round(avg_macro_f1_score,2)}")
    #elif predicting_feature == 'rating_level_num':
        #print(f"(3) Average weighted F1 score = {round(avg_weighted_f1_score,2)}")      
    print(f"(4) Average Percentage Classification accuracy = {round(avg_acc*100,2)}%")

# %% [markdown]
# ### Run the model

# %%
CNN_LSTM_LOP0CV_properties_1(emg_0, emg_1, num_folds=5, predicting_feature='property_id', learning_rate=0.3, num_epochs=30, random_state=num)

# %%
CNN_LSTM_LOP0CV_properties_1(emg_0, emg_1, num_folds=5, predicting_feature='property_id', learning_rate=0.3, num_epochs=30, random_state=num)

# %%
t2 = time.time()

# %%
def find_best_model_for_fold_2(train_dataloader, val_dataloader, learning_rate, num_epochs):

    # Model
    train_model = Linear_model_2()

    # Loss and Optimiser
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(train_model.parameters(), lr=learning_rate, momentum=0.7)

    best_avg_loss = np.inf
    best_model = None
    #best_model_epoch_num = np.inf
    train_loss_lst = []
    val_loss_lst = []
    avg_loss_lst = []

    for epoch in range(num_epochs):  # loop over the dataset multiple times

        #Set the model in training mode
        train_model.train()

        # Initialise the total training and validation loss
        epoch_train_loss = 0
        epoch_val_loss = 0
        avg_loss = 0
        #count_train = 0
        #count_val = 0

        #running_loss = 0.0
        for i, train_data in enumerate(train_dataloader, 0):
            #print(len(train_data))
            #count_train += 1
            # get the inputs; data is a list of [input1, input2, label]
            train_input1, train_labels = train_data #train_input2, 

            #train_labels = train_labels.type(torch.LongTensor)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            train_preds = train_model(train_input1) #, train_input2
            #print(train_labels)#

            train_loss = criterion(train_preds, train_labels)
            train_loss.backward()
            optimizer.step()

            # Update training loss
            epoch_train_loss += train_loss.item()

        # Switch off auto grad for evaluation
        with torch.no_grad():

            # Set the model in evaluation mode
            train_model.eval()

            for j, val_data in enumerate(val_dataloader, 0):
               # count_val += 1
               # print(len(val_data))
            # get the inputs; data is a list of [input1, input2, label]
                val_input1, val_labels = val_data # val_input2, 

                #val_labels = val_labels.type(torch.LongTensor)

                val_preds = train_model(val_input1) #, val_input2

                # Update validation loss
                val_loss = criterion(val_preds, val_labels)

                epoch_val_loss += val_loss.item()
        #print(len(train_dataloader), len(val_dataloader))       
        avg_training_loss = epoch_train_loss / len(train_dataloader) #count_train
        avg_validation_loss = epoch_val_loss / len(val_dataloader) #count_val
        avg_loss = (avg_training_loss + avg_validation_loss) / 2
        
        train_loss_lst.append(avg_training_loss)
        val_loss_lst.append(avg_validation_loss)
        avg_loss_lst.append(avg_loss)
         
        #print(f'epoch {epoch+1}: train loss = {round(avg_training_loss,2)}, val loss = {round(avg_validation_loss,2)}, average loss = {round(avg_loss,2)}')

        if avg_loss < best_avg_loss:
            best_avg_loss = avg_loss
            best_model = train_model.state_dict()

    return best_avg_loss, best_model, train_loss_lst, val_loss_lst, avg_loss_lst   #, avg_loss_lst,

# %%
# Original
def Linear_LOP0CV_properties_2(data, num_folds=5, predicting_feature='property_id', learning_rate=0.01, num_epochs=10, random_state=num, X_dim=2): #, num_inner_folds=5
    # Set fixed random number seed
    torch.manual_seed(num)
    
   # elif predicting_feature == 'rating_level_num':
    #weighted_f1_lst = [] 
    total_conf_mat = 0
    micro_f1_lst = []
    macro_f1_lst = []
    acc_lst = []

    #lst = [6,24,2]#,24]
    
    for participant in sorted(data.participant_id.unique()): # #:lst: #
        print(f'LEAVING PARTICIPANT {participant} OUT:')
        
        # Split the data into training and testing
        training_data = data[data.participant_id != participant] 
        testing_data = data[data.participant_id == participant] 

        # Data preparation
        if X_dim == 2:
            X_train = create_X_2d(training_data, 11)       
            y_train = create_y_train_for_2d_X(training_data, predicting_feature = 'property_id')
            X_test = create_X_2d(testing_data, 11) 
            y_test = create_y_test_for_2d_X(testing_data, predicting_feature = 'property_id')
        elif X_dim == 3:
            X_train = create_X_3d(training_data, 11)       
            y_train = create_y_train_for_3d_X(training_data, predicting_feature = 'property_id')
            X_test = create_X_3d(testing_data, 11) 
            y_test = create_y_test_for_3d_X(testing_data, predicting_feature = 'property_id')

        #print(X_train.shape)
        #print(y_train.shape)
        #print(X_test.shape)
        #print(y_test.shape)
 
        # Create the datasets and dataloaders
        train_dataset = TensorDataset(X_train, y_train) 
        
        test_dataset = TensorDataset(X_test, y_test)
        test_dataloader = torch.utils.data.DataLoader(test_dataset, shuffle=True, batch_size=90) # num_workers=2,       
            
        # Configure the cross-validation procedure
        cv_inner = KFold(n_splits=num_folds, shuffle=True, random_state=num)
                
        min_avg_loss_subject = np.inf
        best_model_subject = None
        
        best_train_loss_lst = None
        best_val_loss_lst = None
        best_avg_loss_lst = None
        best_fold = np.inf

        for fold, (train_ids, val_ids) in enumerate(cv_inner.split(train_dataset)):
            #print(f'FOLD {fold+1}:')
                       
            # Sample elements randomly from a given list of ids, no replacement.
            train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids) # The ids are the same for both
            val_subsampler = torch.utils.data.SubsetRandomSampler(val_ids)

            # Define data loaders for training and testing data in this fold
            train_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=train_subsampler) #, batch_size=100
            val_dataloader = torch.utils.data.DataLoader(train_dataset, sampler=val_subsampler) #, batch_size=20        

            avg_loss_fold, best_model_fold, fold_train_loss_lst, fold_val_loss_lst, fold_avg_loss_lst = find_best_model_for_fold_2(train_dataloader, val_dataloader, learning_rate, num_epochs)
                           
            if avg_loss_fold < min_avg_loss_subject:
                min_avg_loss_subject = avg_loss_fold
                best_model_subject = best_model_fold
                best_train_loss_lst = fold_train_loss_lst
                best_val_loss_lst = fold_val_loss_lst
                best_avg_loss_lst = fold_avg_loss_lst
                best_fold = fold+1

        fig = plt.figure(f"{participant}")                  
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_train_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_val_loss_lst)
        plt.plot(np.linspace(1, num_epochs, num_epochs).astype(int), best_avg_loss_lst)
        plt.title(f"Loss when participant {participant} is left out for fold {best_fold} (lr={learning_rate}, num_epochs ={num_epochs})")
        plt.legend(['train loss', 'val loss', 'avg_loss'])

        # save trained model 
        name = 'model_participant_'+str(participant)+'.pt'
        torch.save(best_model_subject, name)
        print(f'The model for participant {participant} has been saved')
        
        test_model = Linear_model_2()
        test_model.load_state_dict(torch.load(name))

        dataiter = iter(test_dataloader) 
        test_input1, test_labels = dataiter.next() 
    
        test_preds = test_model(test_input1) 
        
        test_preds_np = test_preds.detach().numpy()
        test_predicted_np = np.argmax(test_preds_np, axis = 1)
        
        test_labels_np = test_labels.numpy()       
        

        conf_mat = confusion_matrix(test_labels_np, test_predicted_np, labels=[0, 1, 2, 3, 4])
        macro_f1_score = f1_score(test_labels_np, test_predicted_np, average='macro') 
        micro_f1_score = f1_score(test_labels_np, test_predicted_np, average='micro')  
        acc = accuracy_score(test_labels_np, test_predicted_np)

        print(f"Leaving participant {participant} out")
        print("(1) Confusion matrix:\n", conf_mat)
        print(f"(2) micro F1 score = {round(micro_f1_score,2)}")
        print(f"(3) macro F1 score = {round(macro_f1_score,2)}")    
        print(f"(4) Percentage Classification accuracy = {round(acc*100,2)}%")
        
        total_conf_mat += conf_mat 
        micro_f1_lst.append(micro_f1_score)
        macro_f1_lst.append(macro_f1_score) 
        acc_lst.append(acc)
        print('--------------------------------')
        
    avg_micro_f1_score = sum(micro_f1_lst) / len(micro_f1_lst)
    avg_macro_f1_score = sum(macro_f1_lst) / len(macro_f1_lst)         
    avg_acc = sum(acc_lst) / len(acc_lst)   
    
    print(f'Using Leave One Participant Out CV (LOPOCV):') 
    print("(1) Confusion matrix:\n", total_conf_mat)
    print(f"(2) Average micro F1 score = {round(avg_micro_f1_score,2)}")
    #if predicting_feature == 'property_id':
    print(f"(3) Average macro F1 score = {round(avg_macro_f1_score,2)}")
    #elif predicting_feature == 'rating_level_num':
        #print(f"(3) Average weighted F1 score = {round(avg_weighted_f1_score,2)}")      
    print(f"(4) Average Percentage Classification accuracy = {round(avg_acc*100,2)}%")
